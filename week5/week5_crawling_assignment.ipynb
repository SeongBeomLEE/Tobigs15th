# %% [markdown]
# # Week5 Crawling Assignment
#
# * 네이버 증권 [국내증시 시가총액 페이지](https://finance.naver.com/sise/sise_market_sum.nhn)에 있는 기업 리스트를 읽어옵니다.
#     이 리스트에서 크게 1) 기업명, 2) 링크를 읽어오면 됩니다.
# * 위의 2) 링크를 통해 기업의 상세 컨텐츠에 접근할 수 있으며, 이 상세 컨텐츠의 투자정보를 읽어오면 됩니다.

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## 1. 기업 리스트 수집

# %% [markdown]
# **실습 1. get_finance_list() 작성**
# - Case1-2까지의 코드

# %%
def get_finance_list(html):
    
    soup = BeautifulSoup(html)
    
    elements = soup.select('.box_type_l tbody tr')
    
    finance_list = []
    for element in elements:
        link_element = element.select_one('a')
        result = dict()
        if link_element:
            result['title'] = link_element.text
            result['url'] = 'https://finance.naver.com' + link_element['href']
            finance_list.append(result)
        
    return finance_list

# %% [markdown]
# ### Unit Tests

# %% [markdown]
# **Case 1-1** - 시가총액 페이지에 아무런 기업이 없을 경우

# %%
html = """
<div class="box_type_l">
    <table>
        <tbody>
        </tbody>
    </table>
</div>
"""

finance_list = get_finance_list(html)

assert len(finance_list) == 0

# %% [markdown]
# **Case 1-2** - 시가총액 페이지에 기업이 한 개 있을 경우

# %%
html = """
<div class="box_type_l">
    <table>
        <tbody>
            <tr>
            </tr>
            <tr>
                <td>
                    <a href="/item/main.nhn?code=000001" class="tltle"></a>
                </td>
            </tr>
        </tbody>
    </table>
</div>
"""

finance_list = get_finance_list(html)

assert len(finance_list) == 1

# %% [markdown]
# **Case 1-3** - 시가총액 페이지에 기업이 두 개 있을 경우

# %%
html = """
<div class="box_type_l">
    <table>
        <tbody>
            <tr>
            </tr>
            <tr>
                <td>
                    <a href="/item/main.nhn?code=000001" class="tltle"></a>
                </td>
            </tr>
            <tr>
                <td>
                    <a href="/item/main.nhn?code=000002" class="tltle"></a>
                </td>
            </tr>
        </tbody>
    </table>
</div>
"""

finance_list = get_finance_list(html)

assert len(finance_list) == 2

# %% [markdown]
# **Case 1-4** - 한 개의 기업이 있는 시가총액 페이지 에서 기업 이름을 가져오기

# %%
html = """
<div class="box_type_l">
    <table>
        <tbody>
            <tr>
            </tr>
            <tr>
                <td>
                    <a href="/item/main.nhn?code=000001" class="title">첫 번째 기업</a>
                </td>
            </tr>
        </tbody>
    </table>
</div>
"""

finance_list = get_finance_list(html)

assert len(finance_list) == 1
first_finance = finance_list[0]
assert first_finance['title'] == "첫 번째 기업"

# %% [markdown]
# **Case 1-5** - 한 개의 기업이 있는 시가총액 페이지 에서 기업 이름과 링크를 가져오기

# %%
html = """
<div class="box_type_l">
    <table>
        <tbody>
            <tr>
            </tr>
            <tr>
                <td>
                    <a href="/item/main1.nhn" class="tltle">첫 번째 기업</a>
                </td>
            </tr>
        </tbody>
    </table>
</div>
"""

finance_list = get_finance_list(html)
 
assert len(finance_list) == 1

first_finance = finance_list[0]

assert first_finance['title'] == "첫 번째 기업"
assert first_finance['url'] == "https://finance.naver.com/item/main1.nhn"

# %% [markdown]
# **Case 1-6** - 두 개의 기업이 있는 시가총액 페이지 에서 기업 이름과 링크를 가져오기

# %%
html = """
<div class="box_type_l">
    <table>
        <tbody>
            <tr>
            </tr>
            <tr>
                <td>
                    <a href="/item/main1.nhn" class="tltle">첫 번째 기업</a>
                </td>
            </tr>
            <tr>
                <td>
                    <a href="/item/main2.nhn" class="tltle">두 번째 기업</a>
                </td>
            </tr>
        </tbody>
    </table>
</div>
"""

finance_list = get_finance_list(html)

assert len(finance_list) == 2

first_finance = finance_list[0]

assert first_finance['title'] == "첫 번째 기업"
assert first_finance['url'] == "https://finance.naver.com/item/main1.nhn"

first_finance = finance_list[1]

assert first_finance['title'] == "두 번째 기업"
assert first_finance['url'] == "https://finance.naver.com/item/main2.nhn"

# %% [markdown]
# **Case 1-7** - 실제 네이버 증권 시가총액 한 페이지를 크롤링하기

# %% [markdown]
# 아래 코드를 실행시켜 다음과 같이 결과가 잘 출력되는지 확인해주세요.
# 결과가 잘 출력되지 않는다면 get_finance_list()를 수정해야 합니다!
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-02-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2012.12.31.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-02-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2012.12.31.png)

# %%
# finance_list_url에 네이버 증권 url을 저장합니다.
finance_list_url = "https://finance.naver.com/sise/sise_market_sum.nhn?&page=1"

# 위 URL로 접속한다음 그 응답 결과를 가져옵니다. 이를 response라는 이름의 변수에 할당합니다.
response = requests.get(finance_list_url)

# 국내증시 시가총액 페이지에서 기업 리스트를 읽어옵니다.
finance_list = get_finance_list(response.content)

# 이 기업 리스트를 전부 출력합니다.
finance_list
# Out:
# [{'title': '삼성전자',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005930'},
#  {'title': 'SK하이닉스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000660'},
#  {'title': 'NAVER',
#   'url': 'https://finance.naver.com/item/main.nhn?code=035420'},
#  {'title': 'LG화학',
#   'url': 'https://finance.naver.com/item/main.nhn?code=051910'},
#  {'title': '삼성전자우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005935'},
#  {'title': '현대차',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005380'},
#  {'title': '삼성바이오로직스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=207940'},
#  {'title': '삼성SDI',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006400'},
#  {'title': '카카오',
#   'url': 'https://finance.naver.com/item/main.nhn?code=035720'},
#  {'title': '셀트리온',
#   'url': 'https://finance.naver.com/item/main.nhn?code=068270'},
#  {'title': '기아차',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000270'},
#  {'title': '현대모비스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=012330'},
#  {'title': 'LG전자',
#   'url': 'https://finance.naver.com/item/main.nhn?code=066570'},
#  {'title': 'SK이노베이션',
#   'url': 'https://finance.naver.com/item/main.nhn?code=096770'},
#  {'title': 'POSCO',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005490'},
#  {'title': 'LG생활건강',
#   'url': 'https://finance.naver.com/item/main.nhn?code=051900'},
#  {'title': '삼성물산',
#   'url': 'https://finance.naver.com/item/main.nhn?code=028260'},
#  {'title': '엔씨소프트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=036570'},
#  {'title': 'SK텔레콤',
#   'url': 'https://finance.naver.com/item/main.nhn?code=017670'},
#  {'title': 'SK', 'url': 'https://finance.naver.com/item/main.nhn?code=034730'},
#  {'title': 'KB금융',
#   'url': 'https://finance.naver.com/item/main.nhn?code=105560'},
#  {'title': '신한지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=055550'},
#  {'title': 'LG', 'url': 'https://finance.naver.com/item/main.nhn?code=003550'},
#  {'title': '삼성에스디에스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=018260'},
#  {'title': '삼성생명',
#   'url': 'https://finance.naver.com/item/main.nhn?code=032830'},
#  {'title': '한국전력',
#   'url': 'https://finance.naver.com/item/main.nhn?code=015760'},
#  {'title': '삼성전기',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009150'},
#  {'title': '아모레퍼시픽',
#   'url': 'https://finance.naver.com/item/main.nhn?code=090430'},
#  {'title': '포스코케미칼',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003670'},
#  {'title': '하나금융지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=086790'},
#  {'title': '넷마블',
#   'url': 'https://finance.naver.com/item/main.nhn?code=251270'},
#  {'title': '롯데케미칼',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011170'},
#  {'title': 'KT&G',
#   'url': 'https://finance.naver.com/item/main.nhn?code=033780'},
#  {'title': 'S-Oil',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010950'},
#  {'title': 'SK바이오팜',
#   'url': 'https://finance.naver.com/item/main.nhn?code=326030'},
#  {'title': '한온시스템',
#   'url': 'https://finance.naver.com/item/main.nhn?code=018880'},
#  {'title': 'LG디스플레이',
#   'url': 'https://finance.naver.com/item/main.nhn?code=034220'},
#  {'title': '삼성화재',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000810'},
#  {'title': '한국조선해양',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009540'},
#  {'title': '고려아연',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010130'},
#  {'title': '빅히트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=352820'},
#  {'title': '한화솔루션',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009830'},
#  {'title': '현대글로비스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=086280'},
#  {'title': '우리금융지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=316140'},
#  {'title': 'KT', 'url': 'https://finance.naver.com/item/main.nhn?code=030200'},
#  {'title': '금호석유',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011780'},
#  {'title': '기업은행',
#   'url': 'https://finance.naver.com/item/main.nhn?code=024110'},
#  {'title': '한국타이어앤테크놀로지',
#   'url': 'https://finance.naver.com/item/main.nhn?code=161390'},
#  {'title': '미래에셋대우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006800'},
#  {'title': 'CJ제일제당',
#   'url': 'https://finance.naver.com/item/main.nhn?code=097950'}]

# %% [markdown]
# **실습2. get_all_finance_list() 작성**

# %% [markdown]
# **Case 1-8** - 실제 네이버 증권 시가총액 전체 페이지를 크롤링하기

# %% [markdown]
# 약 1500가량의 모드 회사의 기업 이름과, 링크가 잘 가져와지도록 get_all_finance_list()를 구현해보세요.
# (시간이 조금 걸릴 수 있습니다)

# %%
def get_all_finance_list():
    all_finance_list = []
    # 초기값 설정
    count = 1
    finance_list = [1]
    # 크롤링 할 페이지기 없다면 반복을 중단
    while finance_list:
        
        finance_list_url = "https://finance.naver.com/sise/sise_market_sum.nhn?&page="+ str(count)
        response = requests.get(finance_list_url)
        finance_list = get_finance_list(response.content)
        
        all_finance_list += finance_list
        count +=1
        
    return all_finance_list
    
all_finanace_list = get_all_finance_list()
all_finanace_list
# Out:
# [{'title': '삼성전자',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005930'},
#  {'title': 'SK하이닉스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000660'},
#  {'title': 'NAVER',
#   'url': 'https://finance.naver.com/item/main.nhn?code=035420'},
#  {'title': 'LG화학',
#   'url': 'https://finance.naver.com/item/main.nhn?code=051910'},
#  {'title': '삼성전자우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005935'},
#  {'title': '현대차',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005380'},
#  {'title': '삼성바이오로직스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=207940'},
#  {'title': '삼성SDI',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006400'},
#  {'title': '카카오',
#   'url': 'https://finance.naver.com/item/main.nhn?code=035720'},
#  {'title': '셀트리온',
#   'url': 'https://finance.naver.com/item/main.nhn?code=068270'},
#  {'title': '기아차',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000270'},
#  {'title': '현대모비스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=012330'},
#  {'title': 'LG전자',
#   'url': 'https://finance.naver.com/item/main.nhn?code=066570'},
#  {'title': 'SK이노베이션',
#   'url': 'https://finance.naver.com/item/main.nhn?code=096770'},
#  {'title': 'POSCO',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005490'},
#  {'title': 'LG생활건강',
#   'url': 'https://finance.naver.com/item/main.nhn?code=051900'},
#  {'title': '삼성물산',
#   'url': 'https://finance.naver.com/item/main.nhn?code=028260'},
#  {'title': '엔씨소프트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=036570'},
#  {'title': 'SK텔레콤',
#   'url': 'https://finance.naver.com/item/main.nhn?code=017670'},
#  {'title': 'SK', 'url': 'https://finance.naver.com/item/main.nhn?code=034730'},
#  {'title': 'KB금융',
#   'url': 'https://finance.naver.com/item/main.nhn?code=105560'},
#  {'title': '신한지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=055550'},
#  {'title': 'LG', 'url': 'https://finance.naver.com/item/main.nhn?code=003550'},
#  {'title': '삼성에스디에스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=018260'},
#  {'title': '삼성생명',
#   'url': 'https://finance.naver.com/item/main.nhn?code=032830'},
#  {'title': '한국전력',
#   'url': 'https://finance.naver.com/item/main.nhn?code=015760'},
#  {'title': '삼성전기',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009150'},
#  {'title': '아모레퍼시픽',
#   'url': 'https://finance.naver.com/item/main.nhn?code=090430'},
#  {'title': '포스코케미칼',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003670'},
#  {'title': '하나금융지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=086790'},
#  {'title': '넷마블',
#   'url': 'https://finance.naver.com/item/main.nhn?code=251270'},
#  {'title': '롯데케미칼',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011170'},
#  {'title': 'KT&G',
#   'url': 'https://finance.naver.com/item/main.nhn?code=033780'},
#  {'title': 'S-Oil',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010950'},
#  {'title': 'SK바이오팜',
#   'url': 'https://finance.naver.com/item/main.nhn?code=326030'},
#  {'title': '한온시스템',
#   'url': 'https://finance.naver.com/item/main.nhn?code=018880'},
#  {'title': 'LG디스플레이',
#   'url': 'https://finance.naver.com/item/main.nhn?code=034220'},
#  {'title': '삼성화재',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000810'},
#  {'title': '한국조선해양',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009540'},
#  {'title': '고려아연',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010130'},
#  {'title': '빅히트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=352820'},
#  {'title': '한화솔루션',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009830'},
#  {'title': '현대글로비스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=086280'},
#  {'title': '우리금융지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=316140'},
#  {'title': 'KT', 'url': 'https://finance.naver.com/item/main.nhn?code=030200'},
#  {'title': '금호석유',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011780'},
#  {'title': '기업은행',
#   'url': 'https://finance.naver.com/item/main.nhn?code=024110'},
#  {'title': '한국타이어앤테크놀로지',
#   'url': 'https://finance.naver.com/item/main.nhn?code=161390'},
#  {'title': '미래에셋대우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006800'},
#  {'title': 'CJ제일제당',
#   'url': 'https://finance.naver.com/item/main.nhn?code=097950'},
#  {'title': 'HMM',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011200'},
#  {'title': '현대제철',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004020'},
#  {'title': '아모레G',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002790'},
#  {'title': 'LG유플러스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=032640'},
#  {'title': '오리온',
#   'url': 'https://finance.naver.com/item/main.nhn?code=271560'},
#  {'title': '강원랜드',
#   'url': 'https://finance.naver.com/item/main.nhn?code=035250'},
#  {'title': 'KODEX 200',
#   'url': 'https://finance.naver.com/item/main.nhn?code=069500'},
#  {'title': '한국금융지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=071050'},
#  {'title': '대한항공',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003490'},
#  {'title': '코웨이',
#   'url': 'https://finance.naver.com/item/main.nhn?code=021240'},
#  {'title': 'LG이노텍',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011070'},
#  {'title': '이마트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=139480'},
#  {'title': '현대건설',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000720'},
#  {'title': 'SKC',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011790'},
#  {'title': 'SK케미칼',
#   'url': 'https://finance.naver.com/item/main.nhn?code=285130'},
#  {'title': '녹십자',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006280'},
#  {'title': '신풍제약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=019170'},
#  {'title': '한미사이언스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=008930'},
#  {'title': '유한양행',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000100'},
#  {'title': '현대중공업지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=267250'},
#  {'title': '한미약품',
#   'url': 'https://finance.naver.com/item/main.nhn?code=128940'},
#  {'title': '삼성중공업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010140'},
#  {'title': '두산중공업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=034020'},
#  {'title': '맥쿼리인프라',
#   'url': 'https://finance.naver.com/item/main.nhn?code=088980'},
#  {'title': '동서', 'url': 'https://finance.naver.com/item/main.nhn?code=026960'},
#  {'title': '한진칼',
#   'url': 'https://finance.naver.com/item/main.nhn?code=180640'},
#  {'title': '현대차2우B',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005387'},
#  {'title': 'CJ대한통운',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000120'},
#  {'title': 'GS', 'url': 'https://finance.naver.com/item/main.nhn?code=078930'},
#  {'title': '삼성카드',
#   'url': 'https://finance.naver.com/item/main.nhn?code=029780'},
#  {'title': '롯데지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004990'},
#  {'title': '두산퓨얼셀',
#   'url': 'https://finance.naver.com/item/main.nhn?code=336260'},
#  {'title': '키움증권',
#   'url': 'https://finance.naver.com/item/main.nhn?code=039490'},
#  {'title': '롯데쇼핑',
#   'url': 'https://finance.naver.com/item/main.nhn?code=023530'},
#  {'title': '두산밥캣',
#   'url': 'https://finance.naver.com/item/main.nhn?code=241560'},
#  {'title': '쌍용양회',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003410'},
#  {'title': '한국항공우주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=047810'},
#  {'title': '삼성증권',
#   'url': 'https://finance.naver.com/item/main.nhn?code=016360'},
#  {'title': '일진머티리얼즈',
#   'url': 'https://finance.naver.com/item/main.nhn?code=020150'},
#  {'title': '더존비즈온',
#   'url': 'https://finance.naver.com/item/main.nhn?code=012510'},
#  {'title': '호텔신라',
#   'url': 'https://finance.naver.com/item/main.nhn?code=008770'},
#  {'title': 'GS건설',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006360'},
#  {'title': 'LG화학우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=051915'},
#  {'title': 'NH투자증권',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005940'},
#  {'title': '에스원',
#   'url': 'https://finance.naver.com/item/main.nhn?code=012750'},
#  {'title': '한국가스공사',
#   'url': 'https://finance.naver.com/item/main.nhn?code=036460'},
#  {'title': '만도', 'url': 'https://finance.naver.com/item/main.nhn?code=204320'},
#  {'title': '팬오션',
#   'url': 'https://finance.naver.com/item/main.nhn?code=028670'},
#  {'title': 'DB손해보험',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005830'},
#  {'title': 'OCI',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010060'},
#  {'title': '대우조선해양',
#   'url': 'https://finance.naver.com/item/main.nhn?code=042660'},
#  {'title': 'BGF리테일',
#   'url': 'https://finance.naver.com/item/main.nhn?code=282330'},
#  {'title': 'GS리테일',
#   'url': 'https://finance.naver.com/item/main.nhn?code=007070'},
#  {'title': '한솔케미칼',
#   'url': 'https://finance.naver.com/item/main.nhn?code=014680'},
#  {'title': '포스코인터내셔널',
#   'url': 'https://finance.naver.com/item/main.nhn?code=047050'},
#  {'title': 'CJ', 'url': 'https://finance.naver.com/item/main.nhn?code=001040'},
#  {'title': '한화생명',
#   'url': 'https://finance.naver.com/item/main.nhn?code=088350'},
#  {'title': '현대오토에버',
#   'url': 'https://finance.naver.com/item/main.nhn?code=307950'},
#  {'title': '신세계',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004170'},
#  {'title': '현대차우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005385'},
#  {'title': '삼성엔지니어링',
#   'url': 'https://finance.naver.com/item/main.nhn?code=028050'},
#  {'title': 'TIGER 200',
#   'url': 'https://finance.naver.com/item/main.nhn?code=102110'},
#  {'title': 'DB하이텍',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000990'},
#  {'title': '메리츠증권',
#   'url': 'https://finance.naver.com/item/main.nhn?code=008560'},
#  {'title': '휠라홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=081660'},
#  {'title': '대우건설',
#   'url': 'https://finance.naver.com/item/main.nhn?code=047040'},
#  {'title': '하이트진로',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000080'},
#  {'title': '한샘', 'url': 'https://finance.naver.com/item/main.nhn?code=009240'},
#  {'title': '대한유화',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006650'},
#  {'title': 'LS', 'url': 'https://finance.naver.com/item/main.nhn?code=006260'},
#  {'title': '피비파마',
#   'url': 'https://finance.naver.com/item/main.nhn?code=950210'},
#  {'title': '한화시스템',
#   'url': 'https://finance.naver.com/item/main.nhn?code=272210'},
#  {'title': '한화', 'url': 'https://finance.naver.com/item/main.nhn?code=000880'},
#  {'title': '제일기획',
#   'url': 'https://finance.naver.com/item/main.nhn?code=030000'},
#  {'title': 'DL이앤씨',
#   'url': 'https://finance.naver.com/item/main.nhn?code=375500'},
#  {'title': '대웅', 'url': 'https://finance.naver.com/item/main.nhn?code=003090'},
#  {'title': '현대로템',
#   'url': 'https://finance.naver.com/item/main.nhn?code=064350'},
#  {'title': 'F&F',
#   'url': 'https://finance.naver.com/item/main.nhn?code=007700'},
#  {'title': '현대위아',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011210'},
#  {'title': '현대미포조선',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010620'},
#  {'title': '오뚜기',
#   'url': 'https://finance.naver.com/item/main.nhn?code=007310'},
#  {'title': 'KODEX 200선물인버스2X',
#   'url': 'https://finance.naver.com/item/main.nhn?code=252670'},
#  {'title': '종근당',
#   'url': 'https://finance.naver.com/item/main.nhn?code=185750'},
#  {'title': '한화에어로스페이스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=012450'},
#  {'title': 'BNK금융지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=138930'},
#  {'title': '현대해상',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001450'},
#  {'title': '현대백화점',
#   'url': 'https://finance.naver.com/item/main.nhn?code=069960'},
#  {'title': '메리츠화재',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000060'},
#  {'title': 'KODEX 단기채권',
#   'url': 'https://finance.naver.com/item/main.nhn?code=153130'},
#  {'title': '영원무역',
#   'url': 'https://finance.naver.com/item/main.nhn?code=111770'},
#  {'title': 'KCC',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002380'},
#  {'title': 'HDC현대산업개발',
#   'url': 'https://finance.naver.com/item/main.nhn?code=294870'},
#  {'title': '효성티앤씨',
#   'url': 'https://finance.naver.com/item/main.nhn?code=298020'},
#  {'title': 'KODEX 삼성그룹',
#   'url': 'https://finance.naver.com/item/main.nhn?code=102780'},
#  {'title': 'LS ELECTRIC',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010120'},
#  {'title': '현대엘리베이',
#   'url': 'https://finance.naver.com/item/main.nhn?code=017800'},
#  {'title': 'KODEX 레버리지',
#   'url': 'https://finance.naver.com/item/main.nhn?code=122630'},
#  {'title': 'KODEX MSCI Korea TR',
#   'url': 'https://finance.naver.com/item/main.nhn?code=278540'},
#  {'title': '효성', 'url': 'https://finance.naver.com/item/main.nhn?code=004800'},
#  {'title': 'KODEX 200TR',
#   'url': 'https://finance.naver.com/item/main.nhn?code=278530'},
#  {'title': '녹십자홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005250'},
#  {'title': '두산인프라코어',
#   'url': 'https://finance.naver.com/item/main.nhn?code=042670'},
#  {'title': '농심', 'url': 'https://finance.naver.com/item/main.nhn?code=004370'},
#  {'title': '아이에스동서',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010780'},
#  {'title': '한국앤컴퍼니',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000240'},
#  {'title': '메리츠금융지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=138040'},
#  {'title': '대웅제약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=069620'},
#  {'title': 'TIGER MSCI Korea TR',
#   'url': 'https://finance.naver.com/item/main.nhn?code=310970'},
#  {'title': '씨에스윈드',
#   'url': 'https://finance.naver.com/item/main.nhn?code=112610'},
#  {'title': '롯데관광개발',
#   'url': 'https://finance.naver.com/item/main.nhn?code=032350'},
#  {'title': 'LG생활건강우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=051905'},
#  {'title': 'KODEX 종합채권(AA-이상)액티브',
#   'url': 'https://finance.naver.com/item/main.nhn?code=273130'},
#  {'title': '코오롱인더',
#   'url': 'https://finance.naver.com/item/main.nhn?code=120110'},
#  {'title': '롯데정밀화학',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004000'},
#  {'title': '부광약품',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003000'},
#  {'title': 'SK네트웍스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001740'},
#  {'title': '솔루스첨단소재',
#   'url': 'https://finance.naver.com/item/main.nhn?code=336370'},
#  {'title': '신세계인터내셔날',
#   'url': 'https://finance.naver.com/item/main.nhn?code=031430'},
#  {'title': 'NHN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=181710'},
#  {'title': 'DL', 'url': 'https://finance.naver.com/item/main.nhn?code=000210'},
#  {'title': '지누스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=013890'},
#  {'title': '동원시스템즈',
#   'url': 'https://finance.naver.com/item/main.nhn?code=014820'},
#  {'title': '효성첨단소재',
#   'url': 'https://finance.naver.com/item/main.nhn?code=298050'},
#  {'title': '세방전지',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004490'},
#  {'title': '명신산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009900'},
#  {'title': '한국콜마',
#   'url': 'https://finance.naver.com/item/main.nhn?code=161890'},
#  {'title': 'SK디스커버리',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006120'},
#  {'title': 'LG전자우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=066575'},
#  {'title': 'KBSTAR 200',
#   'url': 'https://finance.naver.com/item/main.nhn?code=148020'},
#  {'title': '한전KPS',
#   'url': 'https://finance.naver.com/item/main.nhn?code=051600'},
#  {'title': 'KG동부제철',
#   'url': 'https://finance.naver.com/item/main.nhn?code=016380'},
#  {'title': '이노션',
#   'url': 'https://finance.naver.com/item/main.nhn?code=214320'},
#  {'title': '다우기술',
#   'url': 'https://finance.naver.com/item/main.nhn?code=023590'},
#  {'title': 'DGB금융지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=139130'},
#  {'title': '영풍', 'url': 'https://finance.naver.com/item/main.nhn?code=000670'},
#  {'title': '한올바이오파마',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009420'},
#  {'title': 'KODEX 인버스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=114800'},
#  {'title': 'JB금융지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=175330'},
#  {'title': '금호타이어',
#   'url': 'https://finance.naver.com/item/main.nhn?code=073240'},
#  {'title': '솔루엠',
#   'url': 'https://finance.naver.com/item/main.nhn?code=248070'},
#  {'title': '한미반도체',
#   'url': 'https://finance.naver.com/item/main.nhn?code=042700'},
#  {'title': '영진약품',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003520'},
#  {'title': '아시아나항공',
#   'url': 'https://finance.naver.com/item/main.nhn?code=020560'},
#  {'title': '에스엘',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005850'},
#  {'title': '보령제약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003850'},
#  {'title': 'KODEX 2차전지산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=305720'},
#  {'title': '롯데칠성',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005300'},
#  {'title': 'LG상사',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001120'},
#  {'title': '코스맥스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=192820'},
#  {'title': '태광산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003240'},
#  {'title': '더블유게임즈',
#   'url': 'https://finance.naver.com/item/main.nhn?code=192080'},
#  {'title': '풍산', 'url': 'https://finance.naver.com/item/main.nhn?code=103140'},
#  {'title': 'KODEX 코스닥150 레버리지',
#   'url': 'https://finance.naver.com/item/main.nhn?code=233740'},
#  {'title': 'GKL',
#   'url': 'https://finance.naver.com/item/main.nhn?code=114090'},
#  {'title': 'CJ CGV',
#   'url': 'https://finance.naver.com/item/main.nhn?code=079160'},
#  {'title': '티와이홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=363280'},
#  {'title': '휴켐스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=069260'},
#  {'title': '후성', 'url': 'https://finance.naver.com/item/main.nhn?code=093370'},
#  {'title': '일양약품',
#   'url': 'https://finance.naver.com/item/main.nhn?code=007570'},
#  {'title': '현대홈쇼핑',
#   'url': 'https://finance.naver.com/item/main.nhn?code=057050'},
#  {'title': '진에어',
#   'url': 'https://finance.naver.com/item/main.nhn?code=272450'},
#  {'title': '파미셀',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005690'},
#  {'title': '코리안리',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003690'},
#  {'title': '동원산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006040'},
#  {'title': 'S&T모티브',
#   'url': 'https://finance.naver.com/item/main.nhn?code=064960'},
#  {'title': '한섬', 'url': 'https://finance.naver.com/item/main.nhn?code=020000'},
#  {'title': '하나투어',
#   'url': 'https://finance.naver.com/item/main.nhn?code=039130'},
#  {'title': '화승엔터프라이즈',
#   'url': 'https://finance.naver.com/item/main.nhn?code=241590'},
#  {'title': 'TIGER 200 IT',
#   'url': 'https://finance.naver.com/item/main.nhn?code=139260'},
#  {'title': '현대그린푸드',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005440'},
#  {'title': 'KODEX 단기채권PLUS',
#   'url': 'https://finance.naver.com/item/main.nhn?code=214980'},
#  {'title': '동국제강',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001230'},
#  {'title': '제주항공',
#   'url': 'https://finance.naver.com/item/main.nhn?code=089590'},
#  {'title': '쿠쿠홈시스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=284740'},
#  {'title': '오리온홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001800'},
#  {'title': '쿠쿠홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=192400'},
#  {'title': '대상', 'url': 'https://finance.naver.com/item/main.nhn?code=001680'},
#  {'title': '롯데하이마트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=071840'},
#  {'title': 'TIGER 단기통안채',
#   'url': 'https://finance.naver.com/item/main.nhn?code=157450'},
#  {'title': 'TIGER TOP10',
#   'url': 'https://finance.naver.com/item/main.nhn?code=292150'},
#  {'title': '대한전선',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001440'},
#  {'title': 'LIG넥스원',
#   'url': 'https://finance.naver.com/item/main.nhn?code=079550'},
#  {'title': 'SK가스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=018670'},
#  {'title': '롯데리츠',
#   'url': 'https://finance.naver.com/item/main.nhn?code=330590'},
#  {'title': '제이알글로벌리츠',
#   'url': 'https://finance.naver.com/item/main.nhn?code=348950'},
#  {'title': '유나이티드제약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=033270'},
#  {'title': '한국단자',
#   'url': 'https://finance.naver.com/item/main.nhn?code=025540'},
#  {'title': '한일시멘트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=300720'},
#  {'title': 'ARIRANG 200',
#   'url': 'https://finance.naver.com/item/main.nhn?code=152100'},
#  {'title': '아모레퍼시픽우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=090435'},
#  {'title': 'ESR켄달스퀘어리츠',
#   'url': 'https://finance.naver.com/item/main.nhn?code=365550'},
#  {'title': 'TIGER KRX2차전지K-뉴딜',
#   'url': 'https://finance.naver.com/item/main.nhn?code=364980'},
#  {'title': '삼성SDI우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006405'},
#  {'title': '롯데제과',
#   'url': 'https://finance.naver.com/item/main.nhn?code=280360'},
#  {'title': '대한해운',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005880'},
#  {'title': '넥센타이어',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002350'},
#  {'title': '두산', 'url': 'https://finance.naver.com/item/main.nhn?code=000150'},
#  {'title': '한세실업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=105630'},
#  {'title': '락앤락',
#   'url': 'https://finance.naver.com/item/main.nhn?code=115390'},
#  {'title': '동원F&B',
#   'url': 'https://finance.naver.com/item/main.nhn?code=049770'},
#  {'title': 'KINDEX 200',
#   'url': 'https://finance.naver.com/item/main.nhn?code=105190'},
#  {'title': '미원상사',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002840'},
#  {'title': 'TIGER 2차전지테마',
#   'url': 'https://finance.naver.com/item/main.nhn?code=305540'},
#  {'title': '제이콘텐트리',
#   'url': 'https://finance.naver.com/item/main.nhn?code=036420'},
#  {'title': '삼양홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000070'},
#  {'title': '대덕전자',
#   'url': 'https://finance.naver.com/item/main.nhn?code=353200'},
#  {'title': '현대건설기계',
#   'url': 'https://finance.naver.com/item/main.nhn?code=267270'},
#  {'title': '케이씨씨글라스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=344820'},
#  {'title': '미래에셋생명',
#   'url': 'https://finance.naver.com/item/main.nhn?code=085620'},
#  {'title': '동아쏘시오홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000640'},
#  {'title': '삼화콘덴서',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001820'},
#  {'title': '효성화학',
#   'url': 'https://finance.naver.com/item/main.nhn?code=298000'},
#  {'title': '대신증권',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003540'},
#  {'title': '동아에스티',
#   'url': 'https://finance.naver.com/item/main.nhn?code=170900'},
#  {'title': '대림건설',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001880'},
#  {'title': 'SK디앤디',
#   'url': 'https://finance.naver.com/item/main.nhn?code=210980'},
#  {'title': '효성중공업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=298040'},
#  {'title': '경동나비엔',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009450'},
#  {'title': '애경산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=018250'},
#  {'title': '일진다이아',
#   'url': 'https://finance.naver.com/item/main.nhn?code=081000'},
#  {'title': '삼양식품',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003230'},
#  {'title': '동양생명',
#   'url': 'https://finance.naver.com/item/main.nhn?code=082640'},
#  {'title': '한전기술',
#   'url': 'https://finance.naver.com/item/main.nhn?code=052690'},
#  {'title': '덴티움',
#   'url': 'https://finance.naver.com/item/main.nhn?code=145720'},
#  {'title': '한진', 'url': 'https://finance.naver.com/item/main.nhn?code=002320'},
#  {'title': 'HDC',
#   'url': 'https://finance.naver.com/item/main.nhn?code=012630'},
#  {'title': '한일현대시멘트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006390'},
#  {'title': 'LG하우시스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=108670'},
#  {'title': '현대일렉트릭',
#   'url': 'https://finance.naver.com/item/main.nhn?code=267260'},
#  {'title': 'NICE',
#   'url': 'https://finance.naver.com/item/main.nhn?code=034310'},
#  {'title': 'TIGER 미국나스닥100',
#   'url': 'https://finance.naver.com/item/main.nhn?code=133690'},
#  {'title': '풀무원',
#   'url': 'https://finance.naver.com/item/main.nhn?code=017810'},
#  {'title': '진원생명과학',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011000'},
#  {'title': '제일약품',
#   'url': 'https://finance.naver.com/item/main.nhn?code=271980'},
#  {'title': '신성이엔지',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011930'},
#  {'title': 'JW중외제약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001060'},
#  {'title': '드림텍',
#   'url': 'https://finance.naver.com/item/main.nhn?code=192650'},
#  {'title': '부산가스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=015350'},
#  {'title': '미래에셋대우2우B',
#   'url': 'https://finance.naver.com/item/main.nhn?code=00680K'},
#  {'title': '롯데정보통신',
#   'url': 'https://finance.naver.com/item/main.nhn?code=286940'},
#  {'title': '코스모신소재',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005070'},
#  {'title': 'KOSEF 200',
#   'url': 'https://finance.naver.com/item/main.nhn?code=069660'},
#  {'title': '유안타증권',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003470'},
#  {'title': 'SPC삼립',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005610'},
#  {'title': '잇츠한불',
#   'url': 'https://finance.naver.com/item/main.nhn?code=226320'},
#  {'title': '우리금융캐피탈',
#   'url': 'https://finance.naver.com/item/main.nhn?code=033660'},
#  {'title': 'HANARO 200',
#   'url': 'https://finance.naver.com/item/main.nhn?code=293180'},
#  {'title': '한화투자증권',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003530'},
#  {'title': '삼양사',
#   'url': 'https://finance.naver.com/item/main.nhn?code=145990'},
#  {'title': '서흥', 'url': 'https://finance.naver.com/item/main.nhn?code=008490'},
#  {'title': '해성디에스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=195870'},
#  {'title': '한진중공업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=097230'},
#  {'title': '율촌화학',
#   'url': 'https://finance.naver.com/item/main.nhn?code=008730'},
#  {'title': '빙그레',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005180'},
#  {'title': '우리종금',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010050'},
#  {'title': 'TIGER 차이나전기차SOLACTIVE',
#   'url': 'https://finance.naver.com/item/main.nhn?code=371460'},
#  {'title': '미원에스씨',
#   'url': 'https://finance.naver.com/item/main.nhn?code=268280'},
#  {'title': '영원무역홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009970'},
#  {'title': 'SGC에너지',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005090'},
#  {'title': '유니드',
#   'url': 'https://finance.naver.com/item/main.nhn?code=014830'},
#  {'title': 'BGF',
#   'url': 'https://finance.naver.com/item/main.nhn?code=027410'},
#  {'title': 'SK렌터카',
#   'url': 'https://finance.naver.com/item/main.nhn?code=068400'},
#  {'title': '롯데손해보험',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000400'},
#  {'title': '케이씨텍',
#   'url': 'https://finance.naver.com/item/main.nhn?code=281820'},
#  {'title': '세아베스틸',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001430'},
#  {'title': '종근당홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001630'},
#  {'title': '코오롱글로벌',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003070'},
#  {'title': '한국토지신탁',
#   'url': 'https://finance.naver.com/item/main.nhn?code=034830'},
#  {'title': '신영증권',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001720'},
#  {'title': '한국카본',
#   'url': 'https://finance.naver.com/item/main.nhn?code=017960'},
#  {'title': 'QV 코스피 변동성 매칭형 양매도 ETN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=550057'},
#  {'title': '한국콜마홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=024720'},
#  {'title': '삼부토건',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001470'},
#  {'title': '한국자산신탁',
#   'url': 'https://finance.naver.com/item/main.nhn?code=123890'},
#  {'title': '서울가스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=017390'},
#  {'title': 'KOSEF 200TR',
#   'url': 'https://finance.naver.com/item/main.nhn?code=294400'},
#  {'title': '디피씨',
#   'url': 'https://finance.naver.com/item/main.nhn?code=026890'},
#  {'title': 'SMART 200TR',
#   'url': 'https://finance.naver.com/item/main.nhn?code=295040'},
#  {'title': '교보증권',
#   'url': 'https://finance.naver.com/item/main.nhn?code=030610'},
#  {'title': '삼성제약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001360'},
#  {'title': 'KODEX 미국FANG플러스(H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=314250'},
#  {'title': '태영건설',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009410'},
#  {'title': 'LF', 'url': 'https://finance.naver.com/item/main.nhn?code=093050'},
#  {'title': 'TIGER KRX BBIG K-뉴딜',
#   'url': 'https://finance.naver.com/item/main.nhn?code=364960'},
#  {'title': '남선알미늄',
#   'url': 'https://finance.naver.com/item/main.nhn?code=008350'},
#  {'title': '광동제약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009290'},
#  {'title': '교촌에프앤비',
#   'url': 'https://finance.naver.com/item/main.nhn?code=339770'},
#  {'title': '대성홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=016710'},
#  {'title': '필룩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=033180'},
#  {'title': '에이프로젠제약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003060'},
#  {'title': '선진', 'url': 'https://finance.naver.com/item/main.nhn?code=136490'},
#  {'title': '모토닉',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009680'},
#  {'title': '한라홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=060980'},
#  {'title': 'KODEX 코스닥150선물인버스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=251340'},
#  {'title': '롯데푸드',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002270'},
#  {'title': '삼성화재우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000815'},
#  {'title': '송원산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004430'},
#  {'title': '한화손해보험',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000370'},
#  {'title': '지역난방공사',
#   'url': 'https://finance.naver.com/item/main.nhn?code=071320'},
#  {'title': '남해화학',
#   'url': 'https://finance.naver.com/item/main.nhn?code=025860'},
#  {'title': 'SBS',
#   'url': 'https://finance.naver.com/item/main.nhn?code=034120'},
#  {'title': '화승인더',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006060'},
#  {'title': '현대퓨처넷',
#   'url': 'https://finance.naver.com/item/main.nhn?code=126560'},
#  {'title': 'DI동일',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001530'},
#  {'title': '일동제약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=249420'},
#  {'title': 'AK홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006840'},
#  {'title': 'KODEX Top5PlusTR',
#   'url': 'https://finance.naver.com/item/main.nhn?code=315930'},
#  {'title': '쌍용차',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003620'},
#  {'title': 'KODEX 자동차',
#   'url': 'https://finance.naver.com/item/main.nhn?code=091180'},
#  {'title': '아세아제지',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002310'},
#  {'title': '스카이라이프',
#   'url': 'https://finance.naver.com/item/main.nhn?code=053210'},
#  {'title': '동화약품',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000020'},
#  {'title': 'SK증권',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001510'},
#  {'title': '고려제강',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002240'},
#  {'title': 'KG케미칼',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001390'},
#  {'title': '신영증권우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001725'},
#  {'title': 'KODEX 코스닥 150',
#   'url': 'https://finance.naver.com/item/main.nhn?code=229200'},
#  {'title': 'KODEX WTI원유선물(H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=261220'},
#  {'title': '삼성 코스피 양매도 5% OTM ETN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=530060'},
#  {'title': '알루코',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001780'},
#  {'title': '케이씨',
#   'url': 'https://finance.naver.com/item/main.nhn?code=029460'},
#  {'title': '엔에스쇼핑',
#   'url': 'https://finance.naver.com/item/main.nhn?code=138250'},
#  {'title': '한독', 'url': 'https://finance.naver.com/item/main.nhn?code=002390'},
#  {'title': '하나제약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=293480'},
#  {'title': 'YG PLUS',
#   'url': 'https://finance.naver.com/item/main.nhn?code=037270'},
#  {'title': '현대에너지솔루션',
#   'url': 'https://finance.naver.com/item/main.nhn?code=322000'},
#  {'title': '진흥기업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002780'},
#  {'title': '신한알파리츠',
#   'url': 'https://finance.naver.com/item/main.nhn?code=293940'},
#  {'title': 'KODEX 코스피',
#   'url': 'https://finance.naver.com/item/main.nhn?code=226490'},
#  {'title': '유진투자증권',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001200'},
#  {'title': '신한 레버리지 WTI원유 선물 ETN(H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=500019'},
#  {'title': '삼성 레버리지 WTI원유 선물 ETN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=530031'},
#  {'title': '맵스리얼티1',
#   'url': 'https://finance.naver.com/item/main.nhn?code=094800'},
#  {'title': '한국금융지주우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=071055'},
#  {'title': '한국철강',
#   'url': 'https://finance.naver.com/item/main.nhn?code=104700'},
#  {'title': '종근당바이오',
#   'url': 'https://finance.naver.com/item/main.nhn?code=063160'},
#  {'title': '태림포장',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011280'},
#  {'title': '동방', 'url': 'https://finance.naver.com/item/main.nhn?code=004140'},
#  {'title': '하이트진로홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000140'},
#  {'title': '환인제약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=016580'},
#  {'title': '대상홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=084690'},
#  {'title': 'LG헬로비전',
#   'url': 'https://finance.naver.com/item/main.nhn?code=037560'},
#  {'title': '무림P&P',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009580'},
#  {'title': '이월드',
#   'url': 'https://finance.naver.com/item/main.nhn?code=084680'},
#  {'title': '아세아시멘트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=183190'},
#  {'title': 'KODEX 선진국MSCI World',
#   'url': 'https://finance.naver.com/item/main.nhn?code=251350'},
#  {'title': '애경유화',
#   'url': 'https://finance.naver.com/item/main.nhn?code=161000'},
#  {'title': '조광피혁',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004700'},
#  {'title': '엘브이엠씨홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=900140'},
#  {'title': '현대차증권',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001500'},
#  {'title': '코리아써키트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=007810'},
#  {'title': '삼진제약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005500'},
#  {'title': '한농화성',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011500'},
#  {'title': '퍼시스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=016800'},
#  {'title': '농심홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=072710'},
#  {'title': '에이프로젠 KIC',
#   'url': 'https://finance.naver.com/item/main.nhn?code=007460'},
#  {'title': '삼성전기우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009155'},
#  {'title': '삼천리',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004690'},
#  {'title': '동성제약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002210'},
#  {'title': '현대리바트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=079430'},
#  {'title': 'JW홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=096760'},
#  {'title': '대원제약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003220'},
#  {'title': '대한제강',
#   'url': 'https://finance.naver.com/item/main.nhn?code=084010'},
#  {'title': '코람코에너지리츠',
#   'url': 'https://finance.naver.com/item/main.nhn?code=357120'},
#  {'title': '이수화학',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005950'},
#  {'title': 'KINDEX 200TR',
#   'url': 'https://finance.naver.com/item/main.nhn?code=332500'},
#  {'title': 'JW생명과학',
#   'url': 'https://finance.naver.com/item/main.nhn?code=234080'},
#  {'title': '이리츠코크렙',
#   'url': 'https://finance.naver.com/item/main.nhn?code=088260'},
#  {'title': '코스모화학',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005420'},
#  {'title': '금호산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002990'},
#  {'title': '경방', 'url': 'https://finance.naver.com/item/main.nhn?code=000050'},
#  {'title': '이연제약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=102460'},
#  {'title': 'CJ4우(전환)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=00104K'},
#  {'title': '티웨이항공',
#   'url': 'https://finance.naver.com/item/main.nhn?code=091810'},
#  {'title': 'TIGER 차이나CSI300',
#   'url': 'https://finance.naver.com/item/main.nhn?code=192090'},
#  {'title': '한국쉘석유',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002960'},
#  {'title': '한솔제지',
#   'url': 'https://finance.naver.com/item/main.nhn?code=213500'},
#  {'title': '한솔테크닉스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004710'},
#  {'title': '조선내화',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000480'},
#  {'title': '유니퀘스트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=077500'},
#  {'title': '대교', 'url': 'https://finance.naver.com/item/main.nhn?code=019680'},
#  {'title': '한일홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003300'},
#  {'title': '삼성출판사',
#   'url': 'https://finance.naver.com/item/main.nhn?code=068290'},
#  {'title': '국도화학',
#   'url': 'https://finance.naver.com/item/main.nhn?code=007690'},
#  {'title': '에어부산',
#   'url': 'https://finance.naver.com/item/main.nhn?code=298690'},
#  {'title': 'TIGER CD금리투자KIS(합성)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=357870'},
#  {'title': '한화3우B',
#   'url': 'https://finance.naver.com/item/main.nhn?code=00088K'},
#  {'title': '그린케미칼',
#   'url': 'https://finance.naver.com/item/main.nhn?code=083420'},
#  {'title': '아이마켓코리아',
#   'url': 'https://finance.naver.com/item/main.nhn?code=122900'},
#  {'title': '삼양패키징',
#   'url': 'https://finance.naver.com/item/main.nhn?code=272550'},
#  {'title': 'KEC',
#   'url': 'https://finance.naver.com/item/main.nhn?code=092220'},
#  {'title': '경보제약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=214390'},
#  {'title': '제일파마홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002620'},
#  {'title': '자화전자',
#   'url': 'https://finance.naver.com/item/main.nhn?code=033240'},
#  {'title': 'KPX케미칼',
#   'url': 'https://finance.naver.com/item/main.nhn?code=025000'},
#  {'title': '동양', 'url': 'https://finance.naver.com/item/main.nhn?code=001520'},
#  {'title': '웅진씽크빅',
#   'url': 'https://finance.naver.com/item/main.nhn?code=095720'},
#  {'title': '삼화페인트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000390'},
#  {'title': '한세예스24홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=016450'},
#  {'title': '세아홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=058650'},
#  {'title': '아모레G3우(전환)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=00279K'},
#  {'title': '자이에스앤디',
#   'url': 'https://finance.naver.com/item/main.nhn?code=317400'},
#  {'title': 'KBSTAR ESG사회책임투자',
#   'url': 'https://finance.naver.com/item/main.nhn?code=290130'},
#  {'title': '신도리코',
#   'url': 'https://finance.naver.com/item/main.nhn?code=029530'},
#  {'title': '코오롱',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002020'},
#  {'title': '현대비앤지스틸',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004560'},
#  {'title': 'S&T홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=036530'},
#  {'title': '경인양행',
#   'url': 'https://finance.naver.com/item/main.nhn?code=012610'},
#  {'title': '경농', 'url': 'https://finance.naver.com/item/main.nhn?code=002100'},
#  {'title': '세진중공업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=075580'},
#  {'title': '휴비스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=079980'},
#  {'title': '금호에이치티',
#   'url': 'https://finance.naver.com/item/main.nhn?code=214330'},
#  {'title': '인지컨트롤스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=023800'},
#  {'title': '동부건설',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005960'},
#  {'title': 'IHQ',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003560'},
#  {'title': '대영포장',
#   'url': 'https://finance.naver.com/item/main.nhn?code=014160'},
#  {'title': 'HANARO MSCI Korea TR',
#   'url': 'https://finance.naver.com/item/main.nhn?code=332940'},
#  {'title': '인스코비',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006490'},
#  {'title': '디티알오토모티브',
#   'url': 'https://finance.naver.com/item/main.nhn?code=007340'},
#  {'title': '세방', 'url': 'https://finance.naver.com/item/main.nhn?code=004360'},
#  {'title': '도화엔지니어링',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002150'},
#  {'title': 'E1', 'url': 'https://finance.naver.com/item/main.nhn?code=017940'},
#  {'title': 'SK케미칼우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=28513K'},
#  {'title': 'KISCO홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001940'},
#  {'title': '센트랄모텍',
#   'url': 'https://finance.naver.com/item/main.nhn?code=308170'},
#  {'title': '신대양제지',
#   'url': 'https://finance.naver.com/item/main.nhn?code=016590'},
#  {'title': 'SBS미디어홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=101060'},
#  {'title': '팜스코',
#   'url': 'https://finance.naver.com/item/main.nhn?code=036580'},
#  {'title': '흥국화재',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000540'},
#  {'title': '삼익THK',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004380'},
#  {'title': '이아이디',
#   'url': 'https://finance.naver.com/item/main.nhn?code=093230'},
#  {'title': '세종공업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=033530'},
#  {'title': '삼영무역',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002810'},
#  {'title': 'TIGER 글로벌4차산업혁신기술(합성 H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=275980'},
#  {'title': '신세계푸드',
#   'url': 'https://finance.naver.com/item/main.nhn?code=031440'},
#  {'title': '대신증권우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003545'},
#  {'title': '대원강업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000430'},
#  {'title': '금호석유우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011785'},
#  {'title': '광주신세계',
#   'url': 'https://finance.naver.com/item/main.nhn?code=037710'},
#  {'title': '풍산홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005810'},
#  {'title': '계룡건설',
#   'url': 'https://finance.naver.com/item/main.nhn?code=013580'},
#  {'title': 'KTB투자증권',
#   'url': 'https://finance.naver.com/item/main.nhn?code=030210'},
#  {'title': '일진홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=015860'},
#  {'title': 'KSS해운',
#   'url': 'https://finance.naver.com/item/main.nhn?code=044450'},
#  {'title': '세아제강',
#   'url': 'https://finance.naver.com/item/main.nhn?code=306200'},
#  {'title': '넥센', 'url': 'https://finance.naver.com/item/main.nhn?code=005720'},
#  {'title': '화승알앤에이',
#   'url': 'https://finance.naver.com/item/main.nhn?code=013520'},
#  {'title': '현대약품',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004310'},
#  {'title': 'CJ제일제당 우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=097955'},
#  {'title': 'DB금융투자',
#   'url': 'https://finance.naver.com/item/main.nhn?code=016610'},
#  {'title': '현대차3우B',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005389'},
#  {'title': 'KPX홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=092230'},
#  {'title': '해태제과식품',
#   'url': 'https://finance.naver.com/item/main.nhn?code=101530'},
#  {'title': '대한제분',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001130'},
#  {'title': '아남전자',
#   'url': 'https://finance.naver.com/item/main.nhn?code=008700'},
#  {'title': 'SK이노베이션우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=096775'},
#  {'title': 'KODEX 골드선물(H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=132030'},
#  {'title': '신세계 I&C',
#   'url': 'https://finance.naver.com/item/main.nhn?code=035510'},
#  {'title': 'KODEX 은행',
#   'url': 'https://finance.naver.com/item/main.nhn?code=091170'},
#  {'title': '아시아나IDT',
#   'url': 'https://finance.naver.com/item/main.nhn?code=267850'},
#  {'title': 'S&T중공업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003570'},
#  {'title': '효성ITX',
#   'url': 'https://finance.naver.com/item/main.nhn?code=094280'},
#  {'title': '수산중공업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=017550'},
#  {'title': 'BYC',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001460'},
#  {'title': '대덕', 'url': 'https://finance.naver.com/item/main.nhn?code=008060'},
#  {'title': '신성통상',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005390'},
#  {'title': '현대상사',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011760'},
#  {'title': '코오롱머티리얼',
#   'url': 'https://finance.naver.com/item/main.nhn?code=144620'},
#  {'title': '코오롱플라스틱',
#   'url': 'https://finance.naver.com/item/main.nhn?code=138490'},
#  {'title': '용평리조트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=070960'},
#  {'title': 'LS전선아시아',
#   'url': 'https://finance.naver.com/item/main.nhn?code=229640'},
#  {'title': '부국증권',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001270'},
#  {'title': 'KBSTAR Fn수소경제테마',
#   'url': 'https://finance.naver.com/item/main.nhn?code=367770'},
#  {'title': 'LS네트웍스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000680'},
#  {'title': 'LG우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003555'},
#  {'title': '동양물산',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002900'},
#  {'title': '신한 WTI원유 선물 ETN(H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=500015'},
#  {'title': '샘표식품',
#   'url': 'https://finance.naver.com/item/main.nhn?code=248170'},
#  {'title': '동성코퍼레이션',
#   'url': 'https://finance.naver.com/item/main.nhn?code=102260'},
#  {'title': 'HSD엔진',
#   'url': 'https://finance.naver.com/item/main.nhn?code=082740'},
#  {'title': '두산퓨얼셀1우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=33626K'},
#  {'title': 'KINDEX 중국본토CSI300',
#   'url': 'https://finance.naver.com/item/main.nhn?code=168580'},
#  {'title': '키다리스튜디오',
#   'url': 'https://finance.naver.com/item/main.nhn?code=020120'},
#  {'title': '오리엔트바이오',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002630'},
#  {'title': '남양유업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003920'},
#  {'title': '한신공영',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004960'},
#  {'title': 'TIGER 코스닥150',
#   'url': 'https://finance.naver.com/item/main.nhn?code=232080'},
#  {'title': '금양', 'url': 'https://finance.naver.com/item/main.nhn?code=001570'},
#  {'title': '삼영전자',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005680'},
#  {'title': '에이블씨엔씨',
#   'url': 'https://finance.naver.com/item/main.nhn?code=078520'},
#  {'title': '일성신약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003120'},
#  {'title': '일신방직',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003200'},
#  {'title': 'SIMPAC',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009160'},
#  {'title': 'KCTC',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009070'},
#  {'title': '대한방직',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001070'},
#  {'title': '포스코강판',
#   'url': 'https://finance.naver.com/item/main.nhn?code=058430'},
#  {'title': '제주은행',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006220'},
#  {'title': '예스코홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=015360'},
#  {'title': '아세아',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002030'},
#  {'title': 'HDC현대EP',
#   'url': 'https://finance.naver.com/item/main.nhn?code=089470'},
#  {'title': '대한제당',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001790'},
#  {'title': 'KOSEF 국고채10년',
#   'url': 'https://finance.naver.com/item/main.nhn?code=148070'},
#  {'title': '한국화장품',
#   'url': 'https://finance.naver.com/item/main.nhn?code=123690'},
#  {'title': '성신양회',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004980'},
#  {'title': '무학', 'url': 'https://finance.naver.com/item/main.nhn?code=033920'},
#  {'title': '한국주철관',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000970'},
#  {'title': 'S-Oil우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010955'},
#  {'title': '유니온머티리얼',
#   'url': 'https://finance.naver.com/item/main.nhn?code=047400'},
#  {'title': '명문제약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=017180'},
#  {'title': '사조산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=007160'},
#  {'title': 'HANARO 단기통안채',
# ...
#  {'title': 'KTis',
#   'url': 'https://finance.naver.com/item/main.nhn?code=058860'},
#  {'title': '대림B&Co',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005750'},
#  {'title': 'STX중공업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=071970'},
#  {'title': '천일고속',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000650'},
#  {'title': '페이퍼코리아',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001020'},
#  {'title': '지투알',
#   'url': 'https://finance.naver.com/item/main.nhn?code=035000'},
#  {'title': '대창단조',
#   'url': 'https://finance.naver.com/item/main.nhn?code=015230'},
#  {'title': '사조씨푸드',
#   'url': 'https://finance.naver.com/item/main.nhn?code=014710'},
#  {'title': '동방아그로',
#   'url': 'https://finance.naver.com/item/main.nhn?code=007590'},
#  {'title': '휴니드',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005870'},
#  {'title': 'DSR',
#   'url': 'https://finance.naver.com/item/main.nhn?code=155660'},
#  {'title': 'KODEX 중국본토CSI300',
#   'url': 'https://finance.naver.com/item/main.nhn?code=283580'},
#  {'title': '한국내화',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010040'},
#  {'title': '한국수출포장',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002200'},
#  {'title': 'KBSTAR 단기국공채액티브',
#   'url': 'https://finance.naver.com/item/main.nhn?code=272560'},
#  {'title': '한창', 'url': 'https://finance.naver.com/item/main.nhn?code=005110'},
#  {'title': '비비안',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002070'},
#  {'title': '한국프랜지',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010100'},
#  {'title': 'TIGER 중장기국채',
#   'url': 'https://finance.naver.com/item/main.nhn?code=302190'},
#  {'title': '가온전선',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000500'},
#  {'title': 'TIGER 유로스탁스50(합성 H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=195930'},
#  {'title': 'KODEX 국고채3년',
#   'url': 'https://finance.naver.com/item/main.nhn?code=114260'},
#  {'title': '동성화학',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005190'},
#  {'title': '방림', 'url': 'https://finance.naver.com/item/main.nhn?code=003610'},
#  {'title': '한솔로지스틱스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009180'},
#  {'title': '삼성 레버리지 천연가스 선물 ETN B',
#   'url': 'https://finance.naver.com/item/main.nhn?code=530068'},
#  {'title': '비상교육',
#   'url': 'https://finance.naver.com/item/main.nhn?code=100220'},
#  {'title': '웅진', 'url': 'https://finance.naver.com/item/main.nhn?code=016880'},
#  {'title': 'KB KTOP30 ETN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=580006'},
#  {'title': '쎌마테라퓨틱스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=015540'},
#  {'title': '제이준코스메틱',
#   'url': 'https://finance.naver.com/item/main.nhn?code=025620'},
#  {'title': '성보화학',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003080'},
#  {'title': 'TIGER 코스닥150 레버리지',
#   'url': 'https://finance.naver.com/item/main.nhn?code=233160'},
#  {'title': '부국철강',
#   'url': 'https://finance.naver.com/item/main.nhn?code=026940'},
#  {'title': '한국종합기술',
#   'url': 'https://finance.naver.com/item/main.nhn?code=023350'},
#  {'title': '녹십자홀딩스2우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005257'},
#  {'title': '참엔지니어링',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009310'},
#  {'title': '호전실업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=111110'},
#  {'title': '조광페인트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004910'},
#  {'title': '삼화왕관',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004450'},
#  {'title': '영보화학',
#   'url': 'https://finance.naver.com/item/main.nhn?code=014440'},
#  {'title': '신영와코루',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005800'},
#  {'title': '세원정공',
#   'url': 'https://finance.naver.com/item/main.nhn?code=021820'},
#  {'title': 'KB 코스피 마운틴 ETN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=580009'},
#  {'title': '우진', 'url': 'https://finance.naver.com/item/main.nhn?code=105840'},
#  {'title': '유성기업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002920'},
#  {'title': '인디에프',
#   'url': 'https://finance.naver.com/item/main.nhn?code=014990'},
#  {'title': '인팩', 'url': 'https://finance.naver.com/item/main.nhn?code=023810'},
#  {'title': 'TIGER KRX바이오K-뉴딜',
#   'url': 'https://finance.naver.com/item/main.nhn?code=364970'},
#  {'title': 'TIGER 차이나HSCEI',
#   'url': 'https://finance.naver.com/item/main.nhn?code=245360'},
#  {'title': '다스코',
#   'url': 'https://finance.naver.com/item/main.nhn?code=058730'},
#  {'title': 'NH프라임리츠',
#   'url': 'https://finance.naver.com/item/main.nhn?code=338100'},
#  {'title': '대원화성',
#   'url': 'https://finance.naver.com/item/main.nhn?code=024890'},
#  {'title': '동양피스톤',
#   'url': 'https://finance.naver.com/item/main.nhn?code=092780'},
#  {'title': 'TIGER 차이나바이오테크SOLACTIVE',
#   'url': 'https://finance.naver.com/item/main.nhn?code=371470'},
#  {'title': 'DSR제강',
#   'url': 'https://finance.naver.com/item/main.nhn?code=069730'},
#  {'title': '만호제강',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001080'},
#  {'title': 'KBSTAR 미국S&P원유생산기업(합성 H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=219390'},
#  {'title': '혜인', 'url': 'https://finance.naver.com/item/main.nhn?code=003010'},
#  {'title': '한익스프레스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=014130'},
#  {'title': 'KODEX KRX300',
#   'url': 'https://finance.naver.com/item/main.nhn?code=292190'},
#  {'title': '문배철강',
#   'url': 'https://finance.naver.com/item/main.nhn?code=008420'},
#  {'title': 'SK디스커버리우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006125'},
#  {'title': '경동인베스트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=012320'},
#  {'title': '미래에셋 전기전자 Core5 ETN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=520004'},
#  {'title': '제일연마',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001560'},
#  {'title': 'TIGER 소프트웨어',
#   'url': 'https://finance.naver.com/item/main.nhn?code=157490'},
#  {'title': 'KBSTAR 중국본토대형주CSI100',
#   'url': 'https://finance.naver.com/item/main.nhn?code=174360'},
#  {'title': '유한양행우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000105'},
#  {'title': 'DL우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000215'},
#  {'title': '삼정펄프',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009770'},
#  {'title': '화인베스틸',
#   'url': 'https://finance.naver.com/item/main.nhn?code=133820'},
#  {'title': '미래에셋대우우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006805'},
#  {'title': '유양디앤유',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011690'},
#  {'title': '삼성 레버리지 China A50 선물 ETN(H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=530023'},
#  {'title': 'ARIRANG 신흥국MSCI(합성 H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=195980'},
#  {'title': 'KB Wise 분할매매 ETN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=580010'},
#  {'title': 'KB KQ 우량주30 ETN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=580007'},
#  {'title': 'TIGER 미국MSCI리츠(합성 H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=182480'},
#  {'title': '삼성 레버리지 은 선물 ETN(H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=530061'},
#  {'title': '일성건설',
#   'url': 'https://finance.naver.com/item/main.nhn?code=013360'},
#  {'title': '코오롱인더우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=120115'},
#  {'title': '화천기공',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000850'},
#  {'title': '동양고속',
#   'url': 'https://finance.naver.com/item/main.nhn?code=084670'},
#  {'title': '키위미디어그룹',
#   'url': 'https://finance.naver.com/item/main.nhn?code=012170'},
#  {'title': 'KODEX 심천ChiNext(합성)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=256750'},
#  {'title': 'CS홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000590'},
#  {'title': '휴스틸',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005010'},
#  {'title': '미래아이앤지',
#   'url': 'https://finance.naver.com/item/main.nhn?code=007120'},
#  {'title': '금비', 'url': 'https://finance.naver.com/item/main.nhn?code=008870'},
#  {'title': '삼성공조',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006660'},
#  {'title': '성안', 'url': 'https://finance.naver.com/item/main.nhn?code=011300'},
#  {'title': '케이탑리츠',
#   'url': 'https://finance.naver.com/item/main.nhn?code=145270'},
#  {'title': 'KODEX 증권',
#   'url': 'https://finance.naver.com/item/main.nhn?code=102970'},
#  {'title': 'TIGER 국채3년',
#   'url': 'https://finance.naver.com/item/main.nhn?code=114820'},
#  {'title': 'QV 하드웨어 TOP5 ETN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=550009'},
#  {'title': 'TIGER 코스피',
#   'url': 'https://finance.naver.com/item/main.nhn?code=277630'},
#  {'title': 'KODEX 미디어&엔터테인먼트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=266360'},
#  {'title': 'KBSTAR 금융채액티브',
#   'url': 'https://finance.naver.com/item/main.nhn?code=336160'},
#  {'title': '선도전기',
#   'url': 'https://finance.naver.com/item/main.nhn?code=007610'},
#  {'title': '메타랩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=090370'},
#  {'title': 'TIGER 200TR',
#   'url': 'https://finance.naver.com/item/main.nhn?code=310960'},
#  {'title': 'TRUE 인버스 2X 나스닥 100 ETN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=570044'},
#  {'title': 'SJM',
#   'url': 'https://finance.naver.com/item/main.nhn?code=123700'},
#  {'title': 'KODEX 200IT TR',
#   'url': 'https://finance.naver.com/item/main.nhn?code=363580'},
#  {'title': '호텔신라우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=008775'},
#  {'title': '평화산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=090080'},
#  {'title': '티에이치엔',
#   'url': 'https://finance.naver.com/item/main.nhn?code=019180'},
#  {'title': '대호에이엘',
#   'url': 'https://finance.naver.com/item/main.nhn?code=069460'},
#  {'title': '한화솔루션우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009835'},
#  {'title': '대림통상',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006570'},
#  {'title': '우진아이엔에스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010400'},
#  {'title': 'TIGER MSCI KOREA ESG리더스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=289260'},
#  {'title': '미래에셋 레버리지 S&P500 ETN(H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=590010'},
#  {'title': 'TIGER 부동산인프라고배당',
#   'url': 'https://finance.naver.com/item/main.nhn?code=329200'},
#  {'title': '신한 레버리지 다우존스지수 선물 ETN(H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=500020'},
#  {'title': 'KODEX 미국달러선물',
#   'url': 'https://finance.naver.com/item/main.nhn?code=261240'},
#  {'title': 'KODEX IT',
#   'url': 'https://finance.naver.com/item/main.nhn?code=266370'},
#  {'title': '대동전자',
#   'url': 'https://finance.naver.com/item/main.nhn?code=008110'},
#  {'title': '미래산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=025560'},
#  {'title': '부국증권우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001275'},
#  {'title': 'TIGER 인버스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=123310'},
#  {'title': '한일철강',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002220'},
#  {'title': '한신기계',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011700'},
#  {'title': '롯데지주우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=00499K'},
#  {'title': '케이비아이동국실업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001620'},
#  {'title': '선창산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002820'},
#  {'title': 'MH에탄올',
#   'url': 'https://finance.naver.com/item/main.nhn?code=023150'},
#  {'title': '두산퓨얼셀2우B',
#   'url': 'https://finance.naver.com/item/main.nhn?code=33626L'},
#  {'title': 'GS우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=078935'},
#  {'title': 'KBSTAR 미국나스닥100',
#   'url': 'https://finance.naver.com/item/main.nhn?code=368590'},
#  {'title': 'TRUE 나스닥 100 ETN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=570051'},
#  {'title': 'TIGER 200IT레버리지',
#   'url': 'https://finance.naver.com/item/main.nhn?code=243880'},
#  {'title': 'WISCOM',
#   'url': 'https://finance.naver.com/item/main.nhn?code=024070'},
#  {'title': '전방', 'url': 'https://finance.naver.com/item/main.nhn?code=000950'},
#  {'title': '우진플라임',
#   'url': 'https://finance.naver.com/item/main.nhn?code=049800'},
#  {'title': '폴루스바이오팜',
#   'url': 'https://finance.naver.com/item/main.nhn?code=007630'},
#  {'title': 'TRUE S&P500 선물 ETN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=570050'},
#  {'title': 'KODEX 코스피대형주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=337140'},
#  {'title': '컨버즈',
#   'url': 'https://finance.naver.com/item/main.nhn?code=109070'},
#  {'title': '주연테크',
#   'url': 'https://finance.naver.com/item/main.nhn?code=044380'},
#  {'title': 'HANARO 200선물레버리지',
#   'url': 'https://finance.naver.com/item/main.nhn?code=304780'},
#  {'title': '한국전자홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006200'},
#  {'title': '평화홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010770'},
#  {'title': '삼성 코스피 풋매도 ETN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=530053'},
#  {'title': 'SMART KRX300',
#   'url': 'https://finance.naver.com/item/main.nhn?code=292500'},
#  {'title': 'SJM홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=025530'},
#  {'title': '체시스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=033250'},
#  {'title': 'KBSTAR 국고채3년선물인버스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=282000'},
#  {'title': '진양산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003780'},
#  {'title': '화천기계',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010660'},
#  {'title': 'TIGER 농산물선물Enhanced(H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=137610'},
#  {'title': '조일알미늄',
#   'url': 'https://finance.naver.com/item/main.nhn?code=018470'},
#  {'title': '유엔젤',
#   'url': 'https://finance.naver.com/item/main.nhn?code=072130'},
#  {'title': 'QV 소프트웨어 TOP5 ETN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=550008'},
#  {'title': 'KODEX 탄소효율그린뉴딜',
#   'url': 'https://finance.naver.com/item/main.nhn?code=375770'},
#  {'title': '두산2우B',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000157'},
#  {'title': '경인전자',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009140'},
#  {'title': 'KODEX 건설',
#   'url': 'https://finance.naver.com/item/main.nhn?code=117700'},
#  {'title': '동원금속',
#   'url': 'https://finance.naver.com/item/main.nhn?code=018500'},
#  {'title': '대교우B',
#   'url': 'https://finance.naver.com/item/main.nhn?code=019685'},
#  {'title': '대신 WTI원유 선물 ETN(H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=510001'},
#  {'title': 'KODEX 미국러셀2000(H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=280930'},
#  {'title': '신송홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006880'},
#  {'title': 'KOSEF 단기자금',
#   'url': 'https://finance.naver.com/item/main.nhn?code=130730'},
#  {'title': '롯데칠성우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005305'},
#  {'title': '한성기업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003680'},
#  {'title': 'TIGER 미국채10년선물',
#   'url': 'https://finance.naver.com/item/main.nhn?code=305080'},
#  {'title': 'KOSEF 통안채1년',
#   'url': 'https://finance.naver.com/item/main.nhn?code=122260'},
#  {'title': 'TRUE 레버리지 천연가스 선물 ETN(H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=570045'},
#  {'title': 'KBSTAR KRX300',
#   'url': 'https://finance.naver.com/item/main.nhn?code=292050'},
#  {'title': '엔케이물산',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009810'},
#  {'title': 'TIGER 미국다우존스30',
#   'url': 'https://finance.naver.com/item/main.nhn?code=245340'},
#  {'title': '이화산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000760'},
#  {'title': '이스타코',
#   'url': 'https://finance.naver.com/item/main.nhn?code=015020'},
#  {'title': '하이트론',
#   'url': 'https://finance.naver.com/item/main.nhn?code=019490'},
#  {'title': '진도', 'url': 'https://finance.naver.com/item/main.nhn?code=088790'},
#  {'title': '솔루스첨단소재2우B',
#   'url': 'https://finance.naver.com/item/main.nhn?code=33637L'},
#  {'title': '대한항공우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003495'},
#  {'title': 'TIGER KRX인터넷K-뉴딜',
#   'url': 'https://finance.naver.com/item/main.nhn?code=365000'},
#  {'title': '태양금속',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004100'},
#  ...]

# %%
len(all_finanace_list)
# Out:
# 1578

# %% [markdown]
# ## 2. 기업 상세 정보 수집

# %% [markdown]
# ## - 주가 정보
#
# - 주가
# - 시가
# - 시가총액
# - 시가총액순위

# %% [markdown]
# **실습 3. get_finance_detail() 작성**

# %%
import re

def get_finance_detail(html):
    
    soup = BeautifulSoup(html)
    finance = dict()
    value_li = soup.select_one('.rate_info')
    value = value_li.select_one('.no_today .blind')
    open_value = value_li.select_one('.no_info .blind')
    
    market_cap_li = soup.select_one('.tab_con1')
    market_cap = market_cap_li.select_one('#_market_sum')
    market_cap_rank = market_cap_li.select_one('.link_site')
    
    if value:
        finance['value'] = int(re.sub('[^0-9]', "", value.text))
    else:
        finance['value'] = value
    
    if open_value:
        finance['open_value'] = int(re.sub('[^0-9]', "", open_value.text))
    else:
        finance['open_value'] = open_value

    if market_cap:
        finance['market_cap(억원)'] = int(re.sub('[^0-9]', "", market_cap.text))
    else:
        finance['market_cap(억원)'] = market_cap        
        
    if market_cap_rank:
        finance['market_cap_rank'] = re.sub('[^0-9가-힣]', "", market_cap_rank.parent.parent.select_one('td').text)
    else:
        finance['market_cap_rank'] = market_cap_rank
        
    return finance

# %% [markdown]
# ### Unit Tests

# %% [markdown]
# **Case 2-1** - 기업정보 페이지에 아무런 내용이 없을 경우

# %%
html = """
<div class="rate_info">
</div>
<div class="tab_con1">
</div>
"""

finance = get_finance_detail(html)

assert finance['value'] == None

# %% [markdown]
# **Case 2-2** - 기업정보 페이지에서 주가 가져오기

# %%
html = """
<div class="rate_info">
    <div class="no_today">
        <div class="blind">
            82,000
        </div>
    </div>
</div>
<div class="tab_con1">
</div>
"""

finance = get_finance_detail(html)

assert finance['value'] == 82000

# %% [markdown]
# **Case 2-3** - 기업정보 페이지에서 시가를 추가로 가져오기
#
# `<div class="rate_info">`에서 "시가"라는 단어를 찾고 html 태그간의 부모-자식 관계를 이용하여 찾아보세요.

# %%
html = """
<div class="rate_info">
    <div class="no_today">
        <div class="blind">
            82,000
        </div>
    </div>
    <table class="no_info">
        <tr>
            <td class="first">
                <span class="sptxt sp_txt3">시가</span>
                            <em class="no_up">

                    <span class="blind">81,200</span>
                    <span class="no8">8</span>
                    <span class="no1">1</span>
                    <span class="shim">,</span>
                    <span class="no2">2</span>
                    <span class="no0">0</span>
                    <span class="no0">0</span>

                </em>
            </td>
        </tr>
    </table>
</div>
<div class="tab_con1">
</div>
"""

finance = get_finance_detail(html)

assert finance['value'] == 82000

assert finance['open_value'] == 81200

# %% [markdown]
# **Case 2-4** - 기업정보 페이지에서 시가총액을 추가로 가져오기
#
# `<div id="tab_con1" class="tab_con1">`에서 "시가총액"이라는 단어를 찾고 html 태그간의 부모-자식 관계를 이용하여 찾아보세요.

# %%
html = """
<div class="rate_info">
</div>
<div id="tab_con1" class="tab_con1">
    <div>
        <table>
            <caption>시가총액</caption>
            <tr class="strong">
                <th scope="row">시가총액</th>
                <td><em id="_market_sum">
                            320조
                                5,773
                    </em>억원
                </td>
            </tr>
        </table>
    </div>
</div>
"""

finance = get_finance_detail(html)

assert finance['market_cap(억원)'] == 3205773

# %% [markdown]
# **Case 2-5-1** - 기업정보 페이지에서 시가총액순위를 추가로 가져오기
#
# `<div id="tab_con1" class="tab_con1">`에서 "시가총액순위"라는 단어를 찾고 html 태그간의 부모-자식 관계를 이용하여 찾아보세요.

# %%
html = """
<div class="rate_info">
</div>
<div id="tab_con1" class="tab_con1">
    <div>
        <table>
            <tr>
                <th scope="row">
                    <a class="link_site" href="/sise/sise_market_sum.nhn">시가총액순위</a>
                </th>
                <td>
                    코스피 <em>1</em>위
                </td>
            </tr>
        </table>
    </div>
</div>
"""

finance = get_finance_detail(html)

assert finance['market_cap_rank'] == '코스피1위'

# %% [markdown]
# **Case 2-5-2** - 기업정보 페이지에 시가총액순위가 없는 경우

# %%
html = """
<div class="rate_info">
</div>
<div id="tab_con1" class="tab_con1">
    <div>
        <table>
            <tr>
            </tr>
        </table>
    </div>
</div>
"""

finance = get_finance_detail(html)

assert finance['market_cap_rank'] == None

# %% [markdown]
# **Case 2-6** - 실제 네이버 증권 상세 페이지를 크롤링하기

# %% [markdown]
# 아래 코드를 실행시켜 다음과 같이 결과가 잘 출력되는지 확인해주세요.
# 결과가 잘 출력되지 않는다면 get_finance_detail()를 수정해야 합니다!
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-02-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2012.21.27.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-02-24%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2012.21.27.png)

# %%
def get_all_finance_detail(response):
    
    finance_detail = get_finance_detail(response.content)
    
    finance = {
        'value' : finance_detail['value'],
        'open_value' : finance_detail['open_value'],
        'market_cap(억원)': finance_detail['market_cap(억원)'],
        'market_cap_rank': finance_detail['market_cap_rank'],
    }

    return finance

# %%
finance_url = "https://finance.naver.com/item/main.nhn?code=005930"

response = requests.get(finance_url)

finance = get_all_finance_detail(response)

finance
# Out:
# {'market_cap(억원)': 5092225,
#  'market_cap_rank': '코스피1위',
#  'open_value': 82000,
#  'value': 85300}

# %% [markdown]
# ### 3. 전체 페이지 읽어오기

# %% [markdown]
# **실습 4. 모든 기업리스트에 대한 상세 정보 crawling**
# finance_summary_list 안에 있는 모든 기업 정보를 가져와 finanace_list에 담도록 구현합니다.

# %%
# get_all_finance_list함수를 활용하여 전체페이지에서 기업 요약정보(기업이름, url)를 받아옵니다.
finance_summary_list = get_all_finance_list()
    
finance_list = []
#######################################################
# finance_summary_list 안에 있는 모든 기업 정보를 가져와 finanace_list에 담도록 구현합니다.
for finance_summary in finance_summary_list:
    
    finance_url = finance_summary['url']
    response = requests.get(finance_url)
    finance = get_all_finance_detail(response)
    
    finance = {
        'title': finance_summary['title'],
        'url'  : finance_summary['url'],
        'value': finance['value'],
        'open_value': finance['open_value'],
        'market_cap(억원)': finance['market_cap(억원)'],
        'market_cap_rank': finance['market_cap_rank']     
    }
    finance_list.append(finance)

#######################################################

finance_list
# Out:
# [{'market_cap(억원)': 5092225,
#   'market_cap_rank': '코스피1위',
#   'open_value': 82000,
#   'title': '삼성전자',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005930',
#   'value': 85300},
#  {'market_cap(억원)': 1081084,
#   'market_cap_rank': '코스피2위',
#   'open_value': 136000,
#   'title': 'SK하이닉스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000660',
#   'value': 148500},
#  {'market_cap(억원)': 629129,
#   'market_cap_rank': '코스피3위',
#   'open_value': 374000,
#   'title': 'NAVER',
#   'url': 'https://finance.naver.com/item/main.nhn?code=035420',
#   'value': 383000},
#  {'market_cap(억원)': 628272,
#   'market_cap_rank': '코스피4위',
#   'open_value': 860000,
#   'title': 'LG화학',
#   'url': 'https://finance.naver.com/item/main.nhn?code=051910',
#   'value': 890000},
#  {'market_cap(억원)': 609759,
#   'market_cap_rank': '코스피5위',
#   'open_value': 72700,
#   'title': '삼성전자우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005935',
#   'value': 74100},
#  {'market_cap(억원)': 523487,
#   'market_cap_rank': '코스피6위',
#   'open_value': 235000,
#   'title': '현대차',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005380',
#   'value': 245000},
#  {'market_cap(억원)': 512779,
#   'market_cap_rank': '코스피7위',
#   'open_value': 747000,
#   'title': '삼성바이오로직스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=207940',
#   'value': 775000},
#  {'market_cap(억원)': 484102,
#   'market_cap_rank': '코스피8위',
#   'open_value': 687000,
#   'title': '삼성SDI',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006400',
#   'value': 704000},
#  {'market_cap(억원)': 429605,
#   'market_cap_rank': '코스피9위',
#   'open_value': 473500,
#   'title': '카카오',
#   'url': 'https://finance.naver.com/item/main.nhn?code=035720',
#   'value': 484500},
#  {'market_cap(억원)': 415885,
#   'market_cap_rank': '코스피10위',
#   'open_value': 282000,
#   'title': '셀트리온',
#   'url': 'https://finance.naver.com/item/main.nhn?code=068270',
#   'value': 308000},
#  {'market_cap(억원)': 312130,
#   'market_cap_rank': '코스피11위',
#   'open_value': 75000,
#   'title': '기아차',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000270',
#   'value': 77000},
#  {'market_cap(억원)': 298947,
#   'market_cap_rank': '코스피12위',
#   'open_value': 310000,
#   'title': '현대모비스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=012330',
#   'value': 314500},
#  {'market_cap(억원)': 252018,
#   'market_cap_rank': '코스피13위',
#   'open_value': 150000,
#   'title': 'LG전자',
#   'url': 'https://finance.naver.com/item/main.nhn?code=066570',
#   'value': 154000},
#  {'market_cap(억원)': 249657,
#   'market_cap_rank': '코스피14위',
#   'open_value': 266500,
#   'title': 'SK이노베이션',
#   'url': 'https://finance.naver.com/item/main.nhn?code=096770',
#   'value': 270000},
#  {'market_cap(억원)': 246739,
#   'market_cap_rank': '코스피15위',
#   'open_value': 274000,
#   'title': 'POSCO',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005490',
#   'value': 283000},
#  {'market_cap(억원)': 244737,
#   'market_cap_rank': '코스피16위',
#   'open_value': 1558000,
#   'title': 'LG생활건강',
#   'url': 'https://finance.naver.com/item/main.nhn?code=051900',
#   'value': 1567000},
#  {'market_cap(억원)': 234543,
#   'market_cap_rank': '코스피17위',
#   'open_value': 122000,
#   'title': '삼성물산',
#   'url': 'https://finance.naver.com/item/main.nhn?code=028260',
#   'value': 125500},
#  {'market_cap(억원)': 213393,
#   'market_cap_rank': '코스피18위',
#   'open_value': 934000,
#   'title': '엔씨소프트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=036570',
#   'value': 972000},
#  {'market_cap(억원)': 203479,
#   'market_cap_rank': '코스피19위',
#   'open_value': 243500,
#   'title': 'SK텔레콤',
#   'url': 'https://finance.naver.com/item/main.nhn?code=017670',
#   'value': 252000},
#  {'market_cap(억원)': 194898,
#   'market_cap_rank': '코스피20위',
#   'open_value': 265000,
#   'title': 'SK',
#   'url': 'https://finance.naver.com/item/main.nhn?code=034730',
#   'value': 277000},
#  {'market_cap(억원)': 186074,
#   'market_cap_rank': '코스피21위',
#   'open_value': 43150,
#   'title': 'KB금융',
#   'url': 'https://finance.naver.com/item/main.nhn?code=105560',
#   'value': 44750},
#  {'market_cap(억원)': 176160,
#   'market_cap_rank': '코스피22위',
#   'open_value': 33150,
#   'title': '신한지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=055550',
#   'value': 34100},
#  {'market_cap(억원)': 166173,
#   'market_cap_rank': '코스피23위',
#   'open_value': 93900,
#   'title': 'LG',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003550',
#   'value': 96300},
#  {'market_cap(억원)': 154756,
#   'market_cap_rank': '코스피24위',
#   'open_value': 195500,
#   'title': '삼성에스디에스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=018260',
#   'value': 200000},
#  {'market_cap(억원)': 153400,
#   'market_cap_rank': '코스피25위',
#   'open_value': 74400,
#   'title': '삼성생명',
#   'url': 'https://finance.naver.com/item/main.nhn?code=032830',
#   'value': 76700},
#  {'market_cap(억원)': 149899,
#   'market_cap_rank': '코스피26위',
#   'open_value': 23150,
#   'title': '한국전력',
#   'url': 'https://finance.naver.com/item/main.nhn?code=015760',
#   'value': 23350},
#  {'market_cap(억원)': 146400,
#   'market_cap_rank': '코스피27위',
#   'open_value': 188500,
#   'title': '삼성전기',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009150',
#   'value': 196000},
#  {'market_cap(억원)': 139716,
#   'market_cap_rank': '코스피28위',
#   'open_value': 232000,
#   'title': '아모레퍼시픽',
#   'url': 'https://finance.naver.com/item/main.nhn?code=090430',
#   'value': 239000},
#  {'market_cap(억원)': 125878,
#   'market_cap_rank': '코스피29위',
#   'open_value': 158000,
#   'title': '포스코케미칼',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003670',
#   'value': 162500},
#  {'market_cap(억원)': 113642,
#   'market_cap_rank': '코스피30위',
#   'open_value': 36950,
#   'title': '하나금융지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=086790',
#   'value': 37850},
#  {'market_cap(억원)': 111652,
#   'market_cap_rank': '코스피31위',
#   'open_value': 123500,
#   'title': '넷마블',
#   'url': 'https://finance.naver.com/item/main.nhn?code=251270',
#   'value': 130000},
#  {'market_cap(억원)': 111052,
#   'market_cap_rank': '코스피32위',
#   'open_value': 302500,
#   'title': '롯데케미칼',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011170',
#   'value': 324000},
#  {'market_cap(억원)': 109559,
#   'market_cap_rank': '코스피33위',
#   'open_value': 78700,
#   'title': 'KT&G',
#   'url': 'https://finance.naver.com/item/main.nhn?code=033780',
#   'value': 79800},
#  {'market_cap(억원)': 99073,
#   'market_cap_rank': '코스피34위',
#   'open_value': 83700,
#   'title': 'S-Oil',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010950',
#   'value': 88000},
#  {'market_cap(억원)': 98675,
#   'market_cap_rank': '코스피35위',
#   'open_value': 122000,
#   'title': 'SK바이오팜',
#   'url': 'https://finance.naver.com/item/main.nhn?code=326030',
#   'value': 126000},
#  {'market_cap(억원)': 85942,
#   'market_cap_rank': '코스피36위',
#   'open_value': 15700,
#   'title': '한온시스템',
#   'url': 'https://finance.naver.com/item/main.nhn?code=018880',
#   'value': 16100},
#  {'market_cap(억원)': 84802,
#   'market_cap_rank': '코스피37위',
#   'open_value': 23400,
#   'title': 'LG디스플레이',
#   'url': 'https://finance.naver.com/item/main.nhn?code=034220',
#   'value': 23700},
#  {'market_cap(억원)': 83143,
#   'market_cap_rank': '코스피38위',
#   'open_value': 173500,
#   'title': '삼성화재',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000810',
#   'value': 175500},
#  {'market_cap(억원)': 8681,
#   'market_cap_rank': '코스피39위',
#   'open_value': 109000,
#   'title': '한국조선해양',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009540',
#   'value': 114000},
#  {'market_cap(억원)': 78499,
#   'market_cap_rank': '코스피40위',
#   'open_value': 415500,
#   'title': '고려아연',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010130',
#   'value': 416000},
#  {'market_cap(억원)': 75522,
#   'market_cap_rank': '코스피41위',
#   'open_value': 211000,
#   'title': '빅히트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=352820',
#   'value': 212000},
#  {'market_cap(억원)': 75376,
#   'market_cap_rank': '코스피42위',
#   'open_value': 45200,
#   'title': '한화솔루션',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009830',
#   'value': 47150},
#  {'market_cap(억원)': 73125,
#   'market_cap_rank': '코스피43위',
#   'open_value': 193000,
#   'title': '현대글로비스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=086280',
#   'value': 195000},
#  {'market_cap(억원)': 7927,
#   'market_cap_rank': '코스피44위',
#   'open_value': 9660,
#   'title': '우리금융지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=316140',
#   'value': 9820},
#  {'market_cap(억원)': 68411,
#   'market_cap_rank': '코스피45위',
#   'open_value': 25800,
#   'title': 'KT',
#   'url': 'https://finance.naver.com/item/main.nhn?code=030200',
#   'value': 26200},
#  {'market_cap(억원)': 67181,
#   'market_cap_rank': '코스피46위',
#   'open_value': 210500,
#   'title': '금호석유',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011780',
#   'value': 220500},
#  {'market_cap(억원)': 62934,
#   'market_cap_rank': '코스피47위',
#   'open_value': 8420,
#   'title': '기업은행',
#   'url': 'https://finance.naver.com/item/main.nhn?code=024110',
#   'value': 8520},
#  {'market_cap(억원)': 62929,
#   'market_cap_rank': '코스피48위',
#   'open_value': 48300,
#   'title': '한국타이어앤테크놀로지',
#   'url': 'https://finance.naver.com/item/main.nhn?code=161390',
#   'value': 50800},
#  {'market_cap(억원)': 62596,
#   'market_cap_rank': '코스피49위',
#   'open_value': 9530,
#   'title': '미래에셋대우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006800',
#   'value': 9700},
#  {'market_cap(억원)': 61873,
#   'market_cap_rank': '코스피50위',
#   'open_value': 408500,
#   'title': 'CJ제일제당',
#   'url': 'https://finance.naver.com/item/main.nhn?code=097950',
#   'value': 411000},
#  {'market_cap(억원)': 6354,
#   'market_cap_rank': '코스피51위',
#   'open_value': 17000,
#   'title': 'HMM',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011200',
#   'value': 18400},
#  {'market_cap(억원)': 54913,
#   'market_cap_rank': '코스피52위',
#   'open_value': 39850,
#   'title': '현대제철',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004020',
#   'value': 41150},
#  {'market_cap(억원)': 53763,
#   'market_cap_rank': '코스피53위',
#   'open_value': 63500,
#   'title': '아모레G',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002790',
#   'value': 65200},
#  {'market_cap(억원)': 53267,
#   'market_cap_rank': '코스피54위',
#   'open_value': 12050,
#   'title': 'LG유플러스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=032640',
#   'value': 12200},
#  {'market_cap(억원)': 53176,
#   'market_cap_rank': '코스피55위',
#   'open_value': 127500,
#   'title': '오리온',
#   'url': 'https://finance.naver.com/item/main.nhn?code=271560',
#   'value': 134500},
#  {'market_cap(억원)': 53057,
#   'market_cap_rank': '코스피56위',
#   'open_value': 24600,
#   'title': '강원랜드',
#   'url': 'https://finance.naver.com/item/main.nhn?code=035250',
#   'value': 24800},
#  {'market_cap(억원)': 52133,
#   'market_cap_rank': None,
#   'open_value': 41385,
#   'title': 'KODEX 200',
#   'url': 'https://finance.naver.com/item/main.nhn?code=069500',
#   'value': 42890},
#  {'market_cap(억원)': 51268,
#   'market_cap_rank': '코스피58위',
#   'open_value': 91500,
#   'title': '한국금융지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=071050',
#   'value': 92000},
#  {'market_cap(억원)': 5260,
#   'market_cap_rank': '코스피59위',
#   'open_value': 28450,
#   'title': '대한항공',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003490',
#   'value': 28850},
#  {'market_cap(억원)': 49446,
#   'market_cap_rank': '코스피60위',
#   'open_value': 66600,
#   'title': '코웨이',
#   'url': 'https://finance.naver.com/item/main.nhn?code=021240',
#   'value': 67000},
#  {'market_cap(억원)': 49228,
#   'market_cap_rank': '코스피61위',
#   'open_value': 204000,
#   'title': 'LG이노텍',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011070',
#   'value': 208000},
#  {'market_cap(억원)': 48365,
#   'market_cap_rank': '코스피62위',
#   'open_value': 172000,
#   'title': '이마트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=139480',
#   'value': 173500},
#  {'market_cap(억원)': 46268,
#   'market_cap_rank': '코스피63위',
#   'open_value': 40450,
#   'title': '현대건설',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000720',
#   'value': 41550},
#  {'market_cap(억원)': 45821,
#   'market_cap_rank': '코스피64위',
#   'open_value': 120500,
#   'title': 'SKC',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011790',
#   'value': 121000},
#  {'market_cap(억원)': 45263,
#   'market_cap_rank': '코스피65위',
#   'open_value': 385000,
#   'title': 'SK케미칼',
#   'url': 'https://finance.naver.com/item/main.nhn?code=285130',
#   'value': 385500},
#  {'market_cap(억원)': 45227,
#   'market_cap_rank': '코스피66위',
#   'open_value': 366000,
#   'title': '녹십자',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006280',
#   'value': 387000},
#  {'market_cap(억원)': 44772,
#   'market_cap_rank': '코스피67위',
#   'open_value': 79100,
#   'title': '신풍제약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=019170',
#   'value': 84500},
#  {'market_cap(억원)': 44488,
#   'market_cap_rank': '코스피68위',
#   'open_value': 62900,
#   'title': '한미사이언스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=008930',
#   'value': 66100},
#  {'market_cap(억원)': 44433,
#   'market_cap_rank': '코스피69위',
#   'open_value': 61600,
#   'title': '유한양행',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000100',
#   'value': 63500},
#  {'market_cap(억원)': 43841,
#   'market_cap_rank': '코스피70위',
#   'open_value': 271500,
#   'title': '현대중공업지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=267250',
#   'value': 277500},
#  {'market_cap(억원)': 42274,
#   'market_cap_rank': '코스피71위',
#   'open_value': 336000,
#   'title': '한미약품',
#   'url': 'https://finance.naver.com/item/main.nhn?code=128940',
#   'value': 350000},
#  {'market_cap(억원)': 42210,
#   'market_cap_rank': '코스피72위',
#   'open_value': 6510,
#   'title': '삼성중공업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010140',
#   'value': 6700},
#  {'market_cap(억원)': 41585,
#   'market_cap_rank': '코스피73위',
#   'open_value': 10250,
#   'title': '두산중공업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=034020',
#   'value': 11100},
#  {'market_cap(억원)': 41313,
#   'market_cap_rank': None,
#   'open_value': 11100,
#   'title': '맥쿼리인프라',
#   'url': 'https://finance.naver.com/item/main.nhn?code=088980',
#   'value': 11100},
#  {'market_cap(억원)': 41076,
#   'market_cap_rank': '코스피75위',
#   'open_value': 40500,
#   'title': '동서',
#   'url': 'https://finance.naver.com/item/main.nhn?code=026960',
#   'value': 41200},
#  {'market_cap(억원)': 4619,
#   'market_cap_rank': '코스피76위',
#   'open_value': 59900,
#   'title': '한진칼',
#   'url': 'https://finance.naver.com/item/main.nhn?code=180640',
#   'value': 61300},
#  {'market_cap(억원)': 39039,
#   'market_cap_rank': '코스피77위',
#   'open_value': 103500,
#   'title': '현대차2우B',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005387',
#   'value': 107000},
#  {'market_cap(억원)': 38211,
#   'market_cap_rank': '코스피78위',
#   'open_value': 165500,
#   'title': 'CJ대한통운',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000120',
#   'value': 167500},
#  {'market_cap(억원)': 37120,
#   'market_cap_rank': '코스피79위',
#   'open_value': 39500,
#   'title': 'GS',
#   'url': 'https://finance.naver.com/item/main.nhn?code=078930',
#   'value': 39950},
#  {'market_cap(억원)': 37017,
#   'market_cap_rank': '코스피80위',
#   'open_value': 31300,
#   'title': '삼성카드',
#   'url': 'https://finance.naver.com/item/main.nhn?code=029780',
#   'value': 31950},
#  {'market_cap(억원)': 35564,
#   'market_cap_rank': '코스피81위',
#   'open_value': 33350,
#   'title': '롯데지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004990',
#   'value': 33900},
#  {'market_cap(억원)': 35105,
#   'market_cap_rank': '코스피82위',
#   'open_value': 52000,
#   'title': '두산퓨얼셀',
#   'url': 'https://finance.naver.com/item/main.nhn?code=336260',
#   'value': 53600},
#  {'market_cap(억원)': 34833,
#   'market_cap_rank': '코스피83위',
#   'open_value': 131500,
#   'title': '키움증권',
#   'url': 'https://finance.naver.com/item/main.nhn?code=039490',
#   'value': 134500},
#  {'market_cap(억원)': 34654,
#   'market_cap_rank': '코스피84위',
#   'open_value': 119000,
#   'title': '롯데쇼핑',
#   'url': 'https://finance.naver.com/item/main.nhn?code=023530',
#   'value': 122500},
#  {'market_cap(억원)': 34586,
#   'market_cap_rank': '코스피85위',
#   'open_value': 33300,
#   'title': '두산밥캣',
#   'url': 'https://finance.naver.com/item/main.nhn?code=241560',
#   'value': 34500},
#  {'market_cap(억원)': 34514,
#   'market_cap_rank': '코스피86위',
#   'open_value': 6770,
#   'title': '쌍용양회',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003410',
#   'value': 6850},
#  {'market_cap(억원)': 34262,
#   'market_cap_rank': '코스피87위',
#   'open_value': 34300,
#   'title': '한국항공우주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=047810',
#   'value': 35150},
#  {'market_cap(억원)': 33934,
#   'market_cap_rank': '코스피88위',
#   'open_value': 37350,
#   'title': '삼성증권',
#   'url': 'https://finance.naver.com/item/main.nhn?code=016360',
#   'value': 38000},
#  {'market_cap(억원)': 33661,
#   'market_cap_rank': '코스피89위',
#   'open_value': 72500,
#   'title': '일진머티리얼즈',
#   'url': 'https://finance.naver.com/item/main.nhn?code=020150',
#   'value': 73000},
#  {'market_cap(억원)': 32756,
#   'market_cap_rank': '코스피90위',
#   'open_value': 106000,
#   'title': '더존비즈온',
#   'url': 'https://finance.naver.com/item/main.nhn?code=012510',
#   'value': 108500},
#  {'market_cap(억원)': 32733,
#   'market_cap_rank': '코스피91위',
#   'open_value': 82900,
#   'title': '호텔신라',
#   'url': 'https://finance.naver.com/item/main.nhn?code=008770',
#   'value': 83400},
#  {'market_cap(억원)': 32193,
#   'market_cap_rank': '코스피92위',
#   'open_value': 36350,
#   'title': 'GS건설',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006360',
#   'value': 37750},
#  {'market_cap(억원)': 31909,
#   'market_cap_rank': '코스피93위',
#   'open_value': 409000,
#   'title': 'LG화학우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=051915',
#   'value': 415000},
#  {'market_cap(억원)': 31799,
#   'market_cap_rank': '코스피94위',
#   'open_value': 11050,
#   'title': 'NH투자증권',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005940',
#   'value': 11300},
#  {'market_cap(억원)': 31539,
#   'market_cap_rank': '코스피95위',
#   'open_value': 81900,
#   'title': '에스원',
#   'url': 'https://finance.naver.com/item/main.nhn?code=012750',
#   'value': 83000},
#  {'market_cap(억원)': 3417,
#   'market_cap_rank': '코스피96위',
#   'open_value': 32650,
#   'title': '한국가스공사',
#   'url': 'https://finance.naver.com/item/main.nhn?code=036460',
#   'value': 32950},
#  {'market_cap(억원)': 3146,
#   'market_cap_rank': '코스피97위',
#   'open_value': 63100,
#   'title': '만도',
#   'url': 'https://finance.naver.com/item/main.nhn?code=204320',
#   'value': 64200},
#  {'market_cap(억원)': 29615,
#   'market_cap_rank': '코스피98위',
#   'open_value': 5580,
#   'title': '팬오션',
#   'url': 'https://finance.naver.com/item/main.nhn?code=028670',
#   'value': 5540},
#  {'market_cap(억원)': 29347,
#   'market_cap_rank': '코스피99위',
#   'open_value': 39600,
#   'title': 'DB손해보험',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005830',
#   'value': 41450},
#  {'market_cap(억원)': 29215,
#   'market_cap_rank': '코스피100위',
#   'open_value': 108500,
#   'title': 'OCI',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010060',
#   'value': 122500},
#  {'market_cap(억원)': 28056,
#   'market_cap_rank': '코스피101위',
#   'open_value': 25650,
#   'title': '대우조선해양',
#   'url': 'https://finance.naver.com/item/main.nhn?code=042660',
#   'value': 26150},
#  {'market_cap(억원)': 28000,
#   'market_cap_rank': '코스피102위',
#   'open_value': 159500,
#   'title': 'BGF리테일',
#   'url': 'https://finance.naver.com/item/main.nhn?code=282330',
#   'value': 162000},
#  {'market_cap(억원)': 27951,
#   'market_cap_rank': '코스피103위',
#   'open_value': 35150,
#   'title': 'GS리테일',
#   'url': 'https://finance.naver.com/item/main.nhn?code=007070',
#   'value': 36300},
#  {'market_cap(억원)': 27941,
#   'market_cap_rank': '코스피104위',
#   'open_value': 235000,
#   'title': '한솔케미칼',
#   'url': 'https://finance.naver.com/item/main.nhn?code=014680',
#   'value': 246500},
#  {'market_cap(억원)': 27759,
#   'market_cap_rank': '코스피105위',
#   'open_value': 21300,
#   'title': '포스코인터내셔널',
#   'url': 'https://finance.naver.com/item/main.nhn?code=047050',
#   'value': 22500},
#  {'market_cap(억원)': 27601,
#   'market_cap_rank': '코스피106위',
#   'open_value': 94100,
#   'title': 'CJ',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001040',
#   'value': 94600},
#  {'market_cap(억원)': 27272,
#   'market_cap_rank': '코스피107위',
#   'open_value': 3150,
#   'title': '한화생명',
#   'url': 'https://finance.naver.com/item/main.nhn?code=088350',
#   'value': 3140},
#  {'market_cap(억원)': 26985,
#   'market_cap_rank': '코스피108위',
#   'open_value': 127000,
#   'title': '현대오토에버',
#   'url': 'https://finance.naver.com/item/main.nhn?code=307950',
#   'value': 128500},
#  {'market_cap(억원)': 26976,
#   'market_cap_rank': '코스피109위',
#   'open_value': 269500,
#   'title': '신세계',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004170',
#   'value': 274000},
#  {'market_cap(억원)': 26183,
#   'market_cap_rank': '코스피110위',
#   'open_value': 105000,
#   'title': '현대차우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005385',
#   'value': 107500},
#  {'market_cap(억원)': 26068,
#   'market_cap_rank': '코스피111위',
#   'open_value': 13000,
#   'title': '삼성엔지니어링',
#   'url': 'https://finance.naver.com/item/main.nhn?code=028050',
#   'value': 13300},
#  {'market_cap(억원)': 25934,
#   'market_cap_rank': None,
#   'open_value': 41210,
#   'title': 'TIGER 200',
#   'url': 'https://finance.naver.com/item/main.nhn?code=102110',
#   'value': 42725},
#  {'market_cap(억원)': 25840,
#   'market_cap_rank': '코스피113위',
#   'open_value': 56600,
#   'title': 'DB하이텍',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000990',
#   'value': 58200},
#  {'market_cap(억원)': 25585,
#   'market_cap_rank': '코스피114위',
#   'open_value': 3745,
#   'title': '메리츠증권',
#   'url': 'https://finance.naver.com/item/main.nhn?code=008560',
#   'value': 3785},
#  {'market_cap(억원)': 25212,
#   'market_cap_rank': '코스피115위',
#   'open_value': 39900,
#   'title': '휠라홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=081660',
#   'value': 41500},
#  {'market_cap(억원)': 25187,
#   'market_cap_rank': '코스피116위',
#   'open_value': 5910,
#   'title': '대우건설',
#   'url': 'https://finance.naver.com/item/main.nhn?code=047040',
#   'value': 6060},
#  {'market_cap(억원)': 24231,
#   'market_cap_rank': '코스피117위',
#   'open_value': 33850,
#   'title': '하이트진로',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000080',
#   'value': 34550},
#  {'market_cap(억원)': 23416,
#   'market_cap_rank': '코스피118위',
#   'open_value': 98700,
#   'title': '한샘',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009240',
#   'value': 99500},
#  {'market_cap(억원)': 23400,
#   'market_cap_rank': '코스피119위',
#   'open_value': 343000,
#   'title': '대한유화',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006650',
#   'value': 360000},
#  {'market_cap(억원)': 23345,
#   'market_cap_rank': '코스피120위',
#   'open_value': 70400,
#   'title': 'LS',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006260',
#   'value': 72500},
#  {'market_cap(억원)': 23107,
#   'market_cap_rank': '코스피121위',
#   'open_value': 34000,
#   'title': '피비파마',
#   'url': 'https://finance.naver.com/item/main.nhn?code=950210',
#   'value': 38450},
#  {'market_cap(억원)': 22983,
#   'market_cap_rank': '코스피122위',
#   'open_value': 19150,
#   'title': '한화시스템',
#   'url': 'https://finance.naver.com/item/main.nhn?code=272210',
#   'value': 20850},
#  {'market_cap(억원)': 22900,
#   'market_cap_rank': '코스피123위',
#   'open_value': 29650,
#   'title': '한화',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000880',
#   'value': 30550},
#  {'market_cap(억원)': 22893,
#   'market_cap_rank': '코스피124위',
#   'open_value': 19700,
#   'title': '제일기획',
#   'url': 'https://finance.naver.com/item/main.nhn?code=030000',
#   'value': 19900},
#  {'market_cap(억원)': 22553,
#   'market_cap_rank': '코스피125위',
#   'open_value': 104000,
#   'title': 'DL이앤씨',
#   'url': 'https://finance.naver.com/item/main.nhn?code=375500',
#   'value': 116500},
#  {'market_cap(억원)': 21949,
#   'market_cap_rank': '코스피126위',
#   'open_value': 36400,
#   'title': '대웅',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003090',
#   'value': 37750},
#  {'market_cap(억원)': 21828,
#   'market_cap_rank': '코스피127위',
#   'open_value': 19450,
#   'title': '현대로템',
#   'url': 'https://finance.naver.com/item/main.nhn?code=064350',
#   'value': 20000},
#  {'market_cap(억원)': 21791,
#   'market_cap_rank': '코스피128위',
#   'open_value': 139500,
#   'title': 'F&F',
#   'url': 'https://finance.naver.com/item/main.nhn?code=007700',
#   'value': 141500},
#  {'market_cap(억원)': 21538,
#   'market_cap_rank': '코스피129위',
#   'open_value': 77100,
#   'title': '현대위아',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011210',
#   'value': 79200},
#  {'market_cap(억원)': 21209,
#   'market_cap_rank': '코스피130위',
#   'open_value': 51200,
#   'title': '현대미포조선',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010620',
#   'value': 53100},
#  {'market_cap(억원)': 2747,
#   'market_cap_rank': '코스피131위',
#   'open_value': 562000,
#   'title': '오뚜기',
#   'url': 'https://finance.naver.com/item/main.nhn?code=007310',
#   'value': 565000},
#  {'market_cap(억원)': 2619,
#   'market_cap_rank': None,
#   'open_value': 2230,
#   'title': 'KODEX 200선물인버스2X',
#   'url': 'https://finance.naver.com/item/main.nhn?code=252670',
#   'value': 2060},
#  {'market_cap(억원)': 19710,
#   'market_cap_rank': '코스피133위',
#   'open_value': 166000,
#   'title': '종근당',
#   'url': 'https://finance.naver.com/item/main.nhn?code=185750',
#   'value': 172500},
#  {'market_cap(억원)': 19695,
#   'market_cap_rank': '코스피134위',
#   'open_value': 38100,
#   'title': '한화에어로스페이스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=012450',
#   'value': 38900},
#  {'market_cap(억원)': 19491,
#   'market_cap_rank': '코스피135위',
#   'open_value': 5970,
#   'title': 'BNK금융지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=138930',
#   'value': 5980},
#  {'market_cap(억원)': 19400,
#   'market_cap_rank': '코스피136위',
#   'open_value': 21250,
#   'title': '현대해상',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001450',
#   'value': 21700},
#  {'market_cap(억원)': 19354,
#   'market_cap_rank': '코스피137위',
#   'open_value': 80500,
#   'title': '현대백화점',
#   'url': 'https://finance.naver.com/item/main.nhn?code=069960',
#   'value': 82700},
#  {'market_cap(억원)': 19240,
#   'market_cap_rank': '코스피138위',
#   'open_value': 15600,
#   'title': '메리츠화재',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000060',
#   'value': 15950},
#  {'market_cap(억원)': 19188,
#   'market_cap_rank': None,
#   'open_value': 102725,
#   'title': 'KODEX 단기채권',
#   'url': 'https://finance.naver.com/item/main.nhn?code=153130',
#   'value': 102730},
#  {'market_cap(억원)': 18234,
#   'market_cap_rank': '코스피140위',
#   'open_value': 38550,
#   'title': '영원무역',
#   'url': 'https://finance.naver.com/item/main.nhn?code=111770',
#   'value': 41150},
#  {'market_cap(억원)': 18128,
#   'market_cap_rank': '코스피141위',
#   'open_value': 199000,
#   'title': 'KCC',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002380',
#   'value': 204000},
#  {'market_cap(억원)': 18125,
#   'market_cap_rank': '코스피142위',
#   'open_value': 26650,
#   'title': 'HDC현대산업개발',
#   'url': 'https://finance.naver.com/item/main.nhn?code=294870',
#   'value': 27500},
#  {'market_cap(억원)': 18090,
#   'market_cap_rank': '코스피143위',
#   'open_value': 394500,
#   'title': '효성티앤씨',
#   'url': 'https://finance.naver.com/item/main.nhn?code=298020',
#   'value': 418000},
#  {'market_cap(억원)': 17984,
#   'market_cap_rank': None,
#   'open_value': 9955,
#   'title': 'KODEX 삼성그룹',
#   'url': 'https://finance.naver.com/item/main.nhn?code=102780',
#   'value': 10230},
#  {'market_cap(억원)': 17970,
#   'market_cap_rank': '코스피145위',
#   'open_value': 59100,
#   'title': 'LS ELECTRIC',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010120',
#   'value': 59900},
#  {'market_cap(억원)': 17959,
#   'market_cap_rank': '코스피146위',
#   'open_value': 43650,
#   'title': '현대엘리베이',
#   'url': 'https://finance.naver.com/item/main.nhn?code=017800',
#   'value': 44000},
#  {'market_cap(억원)': 17601,
#   'market_cap_rank': None,
#   'open_value': 25510,
#   'title': 'KODEX 레버리지',
#   'url': 'https://finance.naver.com/item/main.nhn?code=122630',
#   'value': 27330},
#  {'market_cap(억원)': 17520,
#   'market_cap_rank': None,
#   'open_value': 13270,
#   'title': 'KODEX MSCI Korea TR',
#   'url': 'https://finance.naver.com/item/main.nhn?code=278540',
#   'value': 13795},
#  {'market_cap(억원)': 17468,
#   'market_cap_rank': '코스피149위',
#   'open_value': 81400,
#   'title': '효성',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004800',
#   'value': 82900},
#  {'market_cap(억원)': 17415,
#   'market_cap_rank': None,
#   'open_value': 13330,
#   'title': 'KODEX 200TR',
#   'url': 'https://finance.naver.com/item/main.nhn?code=278530',
#   'value': 13805},
#  {'market_cap(억원)': 17400,
#   'market_cap_rank': '코스피151위',
#   'open_value': 35200,
#   'title': '녹십자홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005250',
#   'value': 37000},
#  {'market_cap(억원)': 17273,
#   'market_cap_rank': '코스피152위',
#   'open_value': 7800,
#   'title': '두산인프라코어',
#   'url': 'https://finance.naver.com/item/main.nhn?code=042670',
#   'value': 7990},
#  {'market_cap(억원)': 17092,
#   'market_cap_rank': '코스피153위',
#   'open_value': 280000,
#   'title': '농심',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004370',
#   'value': 281000},
#  {'market_cap(억원)': 16960,
#   'market_cap_rank': '코스피154위',
#   'open_value': 54400,
#   'title': '아이에스동서',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010780',
#   'value': 54900},
#  {'market_cap(억원)': 16744,
#   'market_cap_rank': '코스피155위',
#   'open_value': 18100,
#   'title': '한국앤컴퍼니',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000240',
#   'value': 18000},
#  {'market_cap(억원)': 16349,
#   'market_cap_rank': '코스피156위',
#   'open_value': 11950,
#   'title': '메리츠금융지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=138040',
#   'value': 12200},
#  {'market_cap(억원)': 16337,
#   'market_cap_rank': '코스피157위',
#   'open_value': 136500,
#   'title': '대웅제약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=069620',
#   'value': 141000},
#  {'market_cap(억원)': 15598,
#   'market_cap_rank': None,
#   'open_value': 16740,
#   'title': 'TIGER MSCI Korea TR',
#   'url': 'https://finance.naver.com/item/main.nhn?code=310970',
#   'value': 17350},
#  {'market_cap(억원)': 15371,
#   'market_cap_rank': '코스피159위',
#   'open_value': 70000,
#   'title': '씨에스윈드',
#   'url': 'https://finance.naver.com/item/main.nhn?code=112610',
#   'value': 72900},
#  {'market_cap(억원)': 14756,
#   'market_cap_rank': '코스피160위',
#   'open_value': 20100,
#   'title': '롯데관광개발',
#   'url': 'https://finance.naver.com/item/main.nhn?code=032350',
#   'value': 21300},
#  {'market_cap(억원)': 14677,
#   'market_cap_rank': '코스피161위',
#   'open_value': 698000,
#   'title': 'LG생활건강우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=051905',
#   'value': 699000},
#  {'market_cap(억원)': 14632,
#   'market_cap_rank': None,
#   'open_value': 109630,
#   'title': 'KODEX 종합채권(AA-이상)액티브',
#   'url': 'https://finance.naver.com/item/main.nhn?code=273130',
#   'value': 109520},
#  {'market_cap(억원)': 14272,
#   'market_cap_rank': '코스피163위',
#   'open_value': 49850,
#   'title': '코오롱인더',
#   'url': 'https://finance.naver.com/item/main.nhn?code=120110',
#   'value': 52900},
#  {'market_cap(억원)': 13932,
#   'market_cap_rank': '코스피164위',
#   'open_value': 52700,
#   'title': '롯데정밀화학',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004000',
#   'value': 54000},
#  {'market_cap(억원)': 13908,
#   'market_cap_rank': '코스피165위',
#   'open_value': 21050,
#   'title': '부광약품',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003000',
#   'value': 21450},
#  {'market_cap(억원)': 13774,
#   'market_cap_rank': '코스피166위',
#   'open_value': 5410,
#   'title': 'SK네트웍스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001740',
#   'value': 5550},
#  {'market_cap(억원)': 13750,
#   'market_cap_rank': '코스피167위',
#   'open_value': 45800,
#   'title': '솔루스첨단소재',
#   'url': 'https://finance.naver.com/item/main.nhn?code=336370',
#   'value': 44950},
#  {'market_cap(억원)': 13709,
#   'market_cap_rank': '코스피168위',
#   'open_value': 183500,
#   'title': '신세계인터내셔날',
#   'url': 'https://finance.naver.com/item/main.nhn?code=031430',
#   'value': 192000},
#  {'market_cap(억원)': 13578,
#   'market_cap_rank': '코스피169위',
#   'open_value': 69200,
#   'title': 'NHN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=181710',
#   'value': 69400},
#  {'market_cap(억원)': 13511,
#   'market_cap_rank': '코스피170위',
#   'open_value': 84000,
#   'title': 'DL',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000210',
#   'value': 87500},
#  {'market_cap(억원)': 13384,
#   'market_cap_rank': '코스피171위',
#   'open_value': 92600,
#   'title': '지누스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=013890',
#   'value': 92900},
#  {'market_cap(억원)': 13373,
#   'market_cap_rank': '코스피172위',
#   'open_value': 50500,
#   'title': '동원시스템즈',
#   'url': 'https://finance.naver.com/item/main.nhn?code=014820',
#   'value': 52200},
#  {'market_cap(억원)': 13126,
#   'market_cap_rank': '코스피173위',
#   'open_value': 282000,
#   'title': '효성첨단소재',
#   'url': 'https://finance.naver.com/item/main.nhn?code=298050',
#   'value': 293000},
#  {'market_cap(억원)': 13062,
#   'market_cap_rank': '코스피174위',
#   'open_value': 92500,
#   'title': '세방전지',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004490',
#   'value': 93300},
#  {'market_cap(억원)': 13049,
#   'market_cap_rank': '코스피175위',
#   'open_value': 31500,
#   'title': '명신산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009900',
#   'value': 32000},
#  {'market_cap(억원)': 12997,
#   'market_cap_rank': '코스피176위',
#   'open_value': 56600,
#   'title': '한국콜마',
#   'url': 'https://finance.naver.com/item/main.nhn?code=161890',
#   'value': 56800},
#  {'market_cap(억원)': 12603,
#   'market_cap_rank': '코스피177위',
#   'open_value': 65800,
#   'title': 'SK디스커버리',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006120',
#   'value': 66200},
#  {'market_cap(억원)': 12580,
#   'market_cap_rank': '코스피178위',
#   'open_value': 70500,
#   'title': 'LG전자우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=066575',
#   'value': 73200},
#  {'market_cap(억원)': 12463,
#   'market_cap_rank': None,
#   'open_value': 41460,
#   'title': 'KBSTAR 200',
#   'url': 'https://finance.naver.com/item/main.nhn?code=148020',
#   'value': 42975},
#  {'market_cap(억원)': 12262,
#   'market_cap_rank': '코스피180위',
#   'open_value': 27050,
#   'title': '한전KPS',
#   'url': 'https://finance.naver.com/item/main.nhn?code=051600',
#   'value': 27250},
#  {'market_cap(억원)': 12251,
#   'market_cap_rank': '코스피181위',
#   'open_value': 11800,
#   'title': 'KG동부제철',
#   'url': 'https://finance.naver.com/item/main.nhn?code=016380',
#   'value': 12250},
#  {'market_cap(억원)': 12240,
#   'market_cap_rank': '코스피182위',
#   'open_value': 60700,
#   'title': '이노션',
#   'url': 'https://finance.naver.com/item/main.nhn?code=214320',
#   'value': 61200},
#  {'market_cap(억원)': 12114,
#   'market_cap_rank': '코스피183위',
#   'open_value': 25700,
#   'title': '다우기술',
#   'url': 'https://finance.naver.com/item/main.nhn?code=023590',
#   'value': 27000},
#  {'market_cap(억원)': 12077,
#   'market_cap_rank': '코스피184위',
#   'open_value': 7140,
#   'title': 'DGB금융지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=139130',
#   'value': 7140},
#  {'market_cap(억원)': 11936,
#   'market_cap_rank': '코스피185위',
#   'open_value': 631000,
#   'title': '영풍',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000670',
#   'value': 648000},
#  {'market_cap(억원)': 11859,
#   'market_cap_rank': '코스피186위',
#   'open_value': 22200,
#   'title': '한올바이오파마',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009420',
#   'value': 22700},
#  {'market_cap(억원)': 11702,
#   'market_cap_rank': None,
#   'open_value': 4030,
#   'title': 'KODEX 인버스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=114800',
#   'value': 3880},
#  {'market_cap(억원)': 11583,
#   'market_cap_rank': '코스피188위',
#   'open_value': 5820,
#   'title': 'JB금융지주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=175330',
#   'value': 5880},
#  {'market_cap(억원)': 11562,
#   'market_cap_rank': '코스피189위',
#   'open_value': 3940,
#   'title': '금호타이어',
#   'url': 'https://finance.naver.com/item/main.nhn?code=073240',
#   'value': 4025},
#  {'market_cap(억원)': 11537,
#   'market_cap_rank': '코스피190위',
#   'open_value': 23300,
#   'title': '솔루엠',
#   'url': 'https://finance.naver.com/item/main.nhn?code=248070',
#   'value': 23500},
#  {'market_cap(억원)': 11485,
#   'market_cap_rank': '코스피191위',
#   'open_value': 21500,
#   'title': '한미반도체',
#   'url': 'https://finance.naver.com/item/main.nhn?code=042700',
#   'value': 22300},
#  {'market_cap(억원)': 11412,
#   'market_cap_rank': '코스피192위',
#   'open_value': 6000,
#   'title': '영진약품',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003520',
#   'value': 6240},
#  {'market_cap(억원)': 11236,
#   'market_cap_rank': '코스피193위',
#   'open_value': 15000,
#   'title': '아시아나항공',
#   'url': 'https://finance.naver.com/item/main.nhn?code=020560',
#   'value': 15100},
#  {'market_cap(억원)': 11207,
#   'market_cap_rank': '코스피194위',
#   'open_value': 22600,
#   'title': '에스엘',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005850',
#   'value': 23250},
#  {'market_cap(억원)': 1945,
#   'market_cap_rank': '코스피195위',
#   'open_value': 20450,
#   'title': '보령제약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003850',
#   'value': 21000},
#  {'market_cap(억원)': 1778,
#   'market_cap_rank': None,
#   'open_value': 18755,
#   'title': 'KODEX 2차전지산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=305720',
#   'value': 19315},
#  {'market_cap(억원)': 1636,
#   'market_cap_rank': '코스피197위',
#   'open_value': 119500,
#   'title': '롯데칠성',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005300',
#   'value': 118500},
#  {'market_cap(억원)': 1601,
#   'market_cap_rank': '코스피198위',
#   'open_value': 26650,
#   'title': 'LG상사',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001120',
#   'value': 27350},
#  {'market_cap(억원)': 1552,
#   'market_cap_rank': '코스피199위',
#   'open_value': 102500,
#   'title': '코스맥스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=192820',
#   'value': 105000},
#  {'market_cap(억원)': 1499,
#   'market_cap_rank': '코스피200위',
#   'open_value': 920000,
#   'title': '태광산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003240',
#   'value': 943000},
#  {'market_cap(억원)': 1492,
#   'market_cap_rank': '코스피201위',
#   'open_value': 56300,
#   'title': '더블유게임즈',
#   'url': 'https://finance.naver.com/item/main.nhn?code=192080',
#   'value': 57100},
#  {'market_cap(억원)': 1229,
#   'market_cap_rank': '코스피202위',
#   'open_value': 34750,
#   'title': '풍산',
#   'url': 'https://finance.naver.com/item/main.nhn?code=103140',
#   'value': 36500},
#  {'market_cap(억원)': 1197,
#   'market_cap_rank': None,
#   'open_value': 12905,
#   'title': 'KODEX 코스닥150 레버리지',
#   'url': 'https://finance.naver.com/item/main.nhn?code=233740',
#   'value': 14045},
#  {'market_cap(억원)': 1175,
#   'market_cap_rank': '코스피204위',
#   'open_value': 16200,
#   'title': 'GKL',
#   'url': 'https://finance.naver.com/item/main.nhn?code=114090',
#   'value': 16450},
#  {'market_cap(억원)': 9968,
#   'market_cap_rank': '코스피205위',
#   'open_value': 27800,
#   'title': 'CJ CGV',
#   'url': 'https://finance.naver.com/item/main.nhn?code=079160',
#   'value': 28400},
#  {'market_cap(억원)': 9882,
#   'market_cap_rank': '코스피206위',
#   'open_value': 23700,
#   'title': '티와이홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=363280',
#   'value': 24600},
#  {'market_cap(억원)': 9586,
#   'market_cap_rank': '코스피207위',
#   'open_value': 23000,
#   'title': '휴켐스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=069260',
#   'value': 23450},
#  {'market_cap(억원)': 9585,
#   'market_cap_rank': '코스피208위',
#   'open_value': 10200,
#   'title': '후성',
#   'url': 'https://finance.naver.com/item/main.nhn?code=093370',
#   'value': 10350},
#  {'market_cap(억원)': 9581,
#   'market_cap_rank': '코스피209위',
#   'open_value': 48700,
#   'title': '일양약품',
#   'url': 'https://finance.naver.com/item/main.nhn?code=007570',
#   'value': 50200},
#  {'market_cap(억원)': 9552,
#   'market_cap_rank': '코스피210위',
#   'open_value': 78100,
#   'title': '현대홈쇼핑',
#   'url': 'https://finance.naver.com/item/main.nhn?code=057050',
#   'value': 79600},
#  {'market_cap(억원)': 9540,
#   'market_cap_rank': '코스피211위',
#   'open_value': 20100,
#   'title': '진에어',
#   'url': 'https://finance.naver.com/item/main.nhn?code=272450',
#   'value': 21200},
#  {'market_cap(억원)': 9533,
#   'market_cap_rank': '코스피212위',
#   'open_value': 15200,
#   'title': '파미셀',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005690',
#   'value': 15900},
#  {'market_cap(억원)': 9497,
#   'market_cap_rank': '코스피213위',
#   'open_value': 7830,
#   'title': '코리안리',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003690',
#   'value': 7890},
#  {'market_cap(억원)': 9488,
#   'market_cap_rank': '코스피214위',
#   'open_value': 259000,
#   'title': '동원산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006040',
#   'value': 258000},
#  {'market_cap(억원)': 9476,
#   'market_cap_rank': '코스피215위',
#   'open_value': 62600,
#   'title': 'S&T모티브',
#   'url': 'https://finance.naver.com/item/main.nhn?code=064960',
#   'value': 64800},
#  {'market_cap(억원)': 9421,
#   'market_cap_rank': '코스피216위',
#   'open_value': 37050,
#   'title': '한섬',
#   'url': 'https://finance.naver.com/item/main.nhn?code=020000',
#   'value': 38250},
#  {'market_cap(억원)': 9339,
#   'market_cap_rank': '코스피217위',
#   'open_value': 65800,
#   'title': '하나투어',
#   'url': 'https://finance.naver.com/item/main.nhn?code=039130',
#   'value': 67000},
#  {'market_cap(억원)': 9052,
#   'market_cap_rank': '코스피218위',
#   'open_value': 14600,
#   'title': '화승엔터프라이즈',
#   'url': 'https://finance.naver.com/item/main.nhn?code=241590',
#   'value': 14950},
#  {'market_cap(억원)': 8993,
#   'market_cap_rank': None,
#   'open_value': 39150,
#   'title': 'TIGER 200 IT',
#   'url': 'https://finance.naver.com/item/main.nhn?code=139260',
#   'value': 40730},
#  {'market_cap(억원)': 8979,
#   'market_cap_rank': '코스피220위',
#   'open_value': 9040,
#   'title': '현대그린푸드',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005440',
#   'value': 9190},
#  {'market_cap(억원)': 8924,
#   'market_cap_rank': None,
#   'open_value': 102990,
#   'title': 'KODEX 단기채권PLUS',
#   'url': 'https://finance.naver.com/item/main.nhn?code=214980',
#   'value': 102990},
#  {'market_cap(억원)': 8923,
#   'market_cap_rank': '코스피222위',
#   'open_value': 8600,
#   'title': '동국제강',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001230',
#   'value': 9350},
#  {'market_cap(억원)': 8913,
#   'market_cap_rank': '코스피223위',
#   'open_value': 22700,
#   'title': '제주항공',
#   'url': 'https://finance.naver.com/item/main.nhn?code=089590',
#   'value': 23150},
#  {'market_cap(억원)': 8840,
#   'market_cap_rank': '코스피224위',
#   'open_value': 38550,
#   'title': '쿠쿠홈시스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=284740',
#   'value': 39400},
#  {'market_cap(억원)': 8833,
#   'market_cap_rank': '코스피225위',
#   'open_value': 13800,
#   'title': '오리온홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001800',
#   'value': 14100},
#  {'market_cap(억원)': 8819,
#   'market_cap_rank': '코스피226위',
#   'open_value': 117500,
#   'title': '쿠쿠홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=192400',
#   'value': 124000},
#  {'market_cap(억원)': 8783,
#   'market_cap_rank': '코스피227위',
#   'open_value': 24900,
#   'title': '대상',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001680',
#   'value': 25350},
#  {'market_cap(억원)': 8770,
#   'market_cap_rank': '코스피228위',
#   'open_value': 36050,
#   'title': '롯데하이마트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=071840',
#   'value': 37150},
#  {'market_cap(억원)': 8766,
#   'market_cap_rank': None,
#   'open_value': 100095,
#   'title': 'TIGER 단기통안채',
#   'url': 'https://finance.naver.com/item/main.nhn?code=157450',
#   'value': 100095},
#  {'market_cap(억원)': 8670,
#   'market_cap_rank': None,
#   'open_value': 14730,
#   'title': 'TIGER TOP10',
#   'url': 'https://finance.naver.com/item/main.nhn?code=292150',
#   'value': 15400},
#  {'market_cap(억원)': 8650,
#   'market_cap_rank': '코스피231위',
#   'open_value': 991,
#   'title': '대한전선',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001440',
#   'value': 1010},
#  {'market_cap(억원)': 8646,
#   'market_cap_rank': '코스피232위',
#   'open_value': 37800,
#   'title': 'LIG넥스원',
#   'url': 'https://finance.naver.com/item/main.nhn?code=079550',
#   'value': 39300},
#  {'market_cap(억원)': 8612,
#   'market_cap_rank': '코스피233위',
#   'open_value': 93400,
#   'title': 'SK가스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=018670',
#   'value': 93300},
#  {'market_cap(억원)': 8581,
#   'market_cap_rank': None,
#   'open_value': 4990,
#   'title': '롯데리츠',
#   'url': 'https://finance.naver.com/item/main.nhn?code=330590',
#   'value': 4990},
#  {'market_cap(억원)': 8578,
#   'market_cap_rank': None,
#   'open_value': 5180,
#   'title': '제이알글로벌리츠',
#   'url': 'https://finance.naver.com/item/main.nhn?code=348950',
#   'value': 5180},
#  {'market_cap(억원)': 8399,
#   'market_cap_rank': '코스피236위',
#   'open_value': 50100,
#   'title': '유나이티드제약',
#   'url': 'https://finance.naver.com/item/main.nhn?code=033270',
#   'value': 51700},
#  {'market_cap(억원)': 8301,
#   'market_cap_rank': '코스피237위',
#   'open_value': 73800,
#   'title': '한국단자',
#   'url': 'https://finance.naver.com/item/main.nhn?code=025540',
#   'value': 79700},
#  {'market_cap(억원)': 8277,
#   'market_cap_rank': '코스피238위',
#   'open_value': 115500,
#   'title': '한일시멘트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=300720',
#   'value': 119500},
#  {'market_cap(억원)': 8229,
#   'market_cap_rank': None,
#   'open_value': 41695,
#   'title': 'ARIRANG 200',
#   'url': 'https://finance.naver.com/item/main.nhn?code=152100',
#   'value': 43195},
#  {'market_cap(억원)': 8203,
#   'market_cap_rank': '코스피240위',
#   'open_value': 76500,
#   'title': '아모레퍼시픽우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=090435',
#   'value': 77700},
#  {'market_cap(억원)': 8194,
#   'market_cap_rank': None,
#   'open_value': 5560,
#   'title': 'ESR켄달스퀘어리츠',
#   'url': 'https://finance.naver.com/item/main.nhn?code=365550',
#   'value': 5720},
#  {'market_cap(억원)': 8192,
#   'market_cap_rank': None,
#   'open_value': 16440,
#   'title': 'TIGER KRX2차전지K-뉴딜',
#   'url': 'https://finance.naver.com/item/main.nhn?code=364980',
#   'value': 16805},
#  {'market_cap(억원)': 8170,
#   'market_cap_rank': '코스피243위',
#   'open_value': 492500,
#   'title': '삼성SDI우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006405',
#   'value': 505000},
#  {'market_cap(억원)': 8149,
#   'market_cap_rank': '코스피244위',
#   'open_value': 126000,
#   'title': '롯데제과',
#   'url': 'https://finance.naver.com/item/main.nhn?code=280360',
#   'value': 127000},
#  {'market_cap(억원)': 8049,
#   'market_cap_rank': '코스피245위',
#   'open_value': 3205,
#   'title': '대한해운',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005880',
#   'value': 3295},
#  {'market_cap(억원)': 8009,
#   'market_cap_rank': '코스피246위',
#   'open_value': 8010,
#   'title': '넥센타이어',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002350',
#   'value': 8200},
#  {'market_cap(억원)': 7989,
#   'market_cap_rank': '코스피247위',
#   'open_value': 47150,
#   'title': '두산',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000150',
#   'value': 48350},
#  {'market_cap(억원)': 7960,
#   'market_cap_rank': '코스피248위',
#   'open_value': 19000,
#   'title': '한세실업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=105630',
#   'value': 19900},
#  {'market_cap(억원)': 7792,
#   'market_cap_rank': '코스피249위',
#   'open_value': 14100,
#   'title': '락앤락',
#   'url': 'https://finance.naver.com/item/main.nhn?code=115390',
#   'value': 14700},
#  {'market_cap(억원)': 7680,
#   'market_cap_rank': '코스피250위',
#   'open_value': 194000,
#   'title': '동원F&B',
#   'url': 'https://finance.naver.com/item/main.nhn?code=049770',
#   'value': 199000},
#  {'market_cap(억원)': 7611,
#   'market_cap_rank': None,
#   'open_value': 41635,
#   'title': 'KINDEX 200',
#   'url': 'https://finance.naver.com/item/main.nhn?code=105190',
#   'value': 43120},
#  {'market_cap(억원)': 7604,
#   'market_cap_rank': '코스피252위',
#   'open_value': 156000,
#   'title': '미원상사',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002840',
#   'value': 153000},
#  {'market_cap(억원)': 7517,
#   'market_cap_rank': None,
#   'open_value': 17020,
#   'title': 'TIGER 2차전지테마',
#   'url': 'https://finance.naver.com/item/main.nhn?code=305540',
#   'value': 17460},
#  {'market_cap(억원)': 7513,
#   'market_cap_rank': '코스피254위',
#   'open_value': 43100,
#   'title': '제이콘텐트리',
#   'url': 'https://finance.naver.com/item/main.nhn?code=036420',
#   'value': 45850},
#  {'market_cap(억원)': 7451,
#   'market_cap_rank': '코스피255위',
#   'open_value': 85400,
#   'title': '삼양홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000070',
#   'value': 87000},
#  {'market_cap(억원)': 7338,
#   'market_cap_rank': '코스피256위',
#   'open_value': 14050,
#   'title': '대덕전자',
#   'url': 'https://finance.naver.com/item/main.nhn?code=353200',
#   'value': 14850},
#  {'market_cap(억원)': 7329,
#   'market_cap_rank': '코스피257위',
#   'open_value': 36500,
#   'title': '현대건설기계',
#   'url': 'https://finance.naver.com/item/main.nhn?code=267270',
#   'value': 37200},
#  {'market_cap(억원)': 7259,
#   'market_cap_rank': '코스피258위',
#   'open_value': 44200,
#   'title': '케이씨씨글라스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=344820',
#   'value': 45450},
#  {'market_cap(억원)': 7213,
#   'market_cap_rank': '코스피259위',
#   'open_value': 3995,
#   'title': '미래에셋생명',
#   'url': 'https://finance.naver.com/item/main.nhn?code=085620',
#   'value': 4075},
#  {'market_cap(억원)': 7202,
#   'market_cap_rank': '코스피260위',
#   'open_value': 115500,
#   'title': '동아쏘시오홀딩스',
# ...
#   'market_cap_rank': None,
#   'open_value': 111310,
#   'title': 'TIGER 국채3년',
#   'url': 'https://finance.naver.com/item/main.nhn?code=114820',
#   'value': 111310},
#  {'market_cap(억원)': 667,
#   'market_cap_rank': None,
#   'open_value': 32445,
#   'title': 'QV 하드웨어 TOP5 ETN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=550009',
#   'value': 33360},
#  {'market_cap(억원)': 645,
#   'market_cap_rank': None,
#   'open_value': 30560,
#   'title': 'TIGER 코스피',
#   'url': 'https://finance.naver.com/item/main.nhn?code=277630',
#   'value': 31485},
#  {'market_cap(억원)': 634,
#   'market_cap_rank': None,
#   'open_value': 21210,
#   'title': 'KODEX 미디어&엔터테인먼트',
#   'url': 'https://finance.naver.com/item/main.nhn?code=266360',
#   'value': 21850},
#  {'market_cap(억원)': 631,
#   'market_cap_rank': None,
#   'open_value': 103390,
#   'title': 'KBSTAR 금융채액티브',
#   'url': 'https://finance.naver.com/item/main.nhn?code=336160',
#   'value': 103500},
#  {'market_cap(억원)': 631,
#   'market_cap_rank': '코스피919위',
#   'open_value': 3420,
#   'title': '선도전기',
#   'url': 'https://finance.naver.com/item/main.nhn?code=007610',
#   'value': 3505},
#  {'market_cap(억원)': 630,
#   'market_cap_rank': '코스피920위',
#   'open_value': 996,
#   'title': '메타랩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=090370',
#   'value': 989},
#  {'market_cap(억원)': 629,
#   'market_cap_rank': None,
#   'open_value': 21715,
#   'title': 'TIGER 200TR',
#   'url': 'https://finance.naver.com/item/main.nhn?code=310960',
#   'value': 22480},
#  {'market_cap(억원)': 628,
#   'market_cap_rank': None,
#   'open_value': 2185,
#   'title': 'TRUE 인버스 2X 나스닥 100 ETN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=570044',
#   'value': 2095},
#  {'market_cap(억원)': 627,
#   'market_cap_rank': '코스피923위',
#   'open_value': 3945,
#   'title': 'SJM',
#   'url': 'https://finance.naver.com/item/main.nhn?code=123700',
#   'value': 4020},
#  {'market_cap(억원)': 625,
#   'market_cap_rank': None,
#   'open_value': 14595,
#   'title': 'KODEX 200IT TR',
#   'url': 'https://finance.naver.com/item/main.nhn?code=363580',
#   'value': 15255},
#  {'market_cap(억원)': 623,
#   'market_cap_rank': '코스피925위',
#   'open_value': 82600,
#   'title': '호텔신라우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=008775',
#   'value': 82900},
#  {'market_cap(억원)': 623,
#   'market_cap_rank': '코스피926위',
#   'open_value': 1120,
#   'title': '평화산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=090080',
#   'value': 1135},
#  {'market_cap(억원)': 619,
#   'market_cap_rank': '코스피927위',
#   'open_value': 3255,
#   'title': '티에이치엔',
#   'url': 'https://finance.naver.com/item/main.nhn?code=019180',
#   'value': 3440},
#  {'market_cap(억원)': 616,
#   'market_cap_rank': '코스피928위',
#   'open_value': 2190,
#   'title': '대호에이엘',
#   'url': 'https://finance.naver.com/item/main.nhn?code=069460',
#   'value': 2270},
#  {'market_cap(억원)': 616,
#   'market_cap_rank': '코스피929위',
#   'open_value': 52500,
#   'title': '한화솔루션우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009835',
#   'value': 54800},
#  {'market_cap(억원)': 614,
#   'market_cap_rank': '코스피930위',
#   'open_value': 3990,
#   'title': '대림통상',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006570',
#   'value': 4030},
#  {'market_cap(억원)': 612,
#   'market_cap_rank': '코스피931위',
#   'open_value': 7910,
#   'title': '우진아이엔에스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010400',
#   'value': 8030},
#  {'market_cap(억원)': 609,
#   'market_cap_rank': None,
#   'open_value': 11845,
#   'title': 'TIGER MSCI KOREA ESG리더스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=289260',
#   'value': 12310},
#  {'market_cap(억원)': 609,
#   'market_cap_rank': None,
#   'open_value': 29750,
#   'title': '미래에셋 레버리지 S&P500 ETN(H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=590010',
#   'value': 30450},
#  {'market_cap(억원)': 606,
#   'market_cap_rank': None,
#   'open_value': 4975,
#   'title': 'TIGER 부동산인프라고배당',
#   'url': 'https://finance.naver.com/item/main.nhn?code=329200',
#   'value': 5025},
#  {'market_cap(억원)': 602,
#   'market_cap_rank': None,
#   'open_value': 28940,
#   'title': '신한 레버리지 다우존스지수 선물 ETN(H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=500020',
#   'value': 30100},
#  {'market_cap(억원)': 602,
#   'market_cap_rank': None,
#   'open_value': 9855,
#   'title': 'KODEX 미국달러선물',
#   'url': 'https://finance.naver.com/item/main.nhn?code=261240',
#   'value': 9820},
#  {'market_cap(억원)': 601,
#   'market_cap_rank': None,
#   'open_value': 21270,
#   'title': 'KODEX IT',
#   'url': 'https://finance.naver.com/item/main.nhn?code=266370',
#   'value': 22250},
#  {'market_cap(억원)': 593,
#   'market_cap_rank': '코스피938위',
#   'open_value': 5500,
#   'title': '대동전자',
#   'url': 'https://finance.naver.com/item/main.nhn?code=008110',
#   'value': 5650},
#  {'market_cap(억원)': 593,
#   'market_cap_rank': '코스피939위',
#   'open_value': 3095,
#   'title': '미래산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=025560',
#   'value': 3175},
#  {'market_cap(억원)': 588,
#   'market_cap_rank': '코스피940위',
#   'open_value': 19600,
#   'title': '부국증권우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001275',
#   'value': 19600},
#  {'market_cap(억원)': 586,
#   'market_cap_rank': None,
#   'open_value': 4450,
#   'title': 'TIGER 인버스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=123310',
#   'value': 4275},
#  {'market_cap(억원)': 585,
#   'market_cap_rank': '코스피942위',
#   'open_value': 2155,
#   'title': '한일철강',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002220',
#   'value': 2215},
#  {'market_cap(억원)': 581,
#   'market_cap_rank': '코스피943위',
#   'open_value': 1755,
#   'title': '한신기계',
#   'url': 'https://finance.naver.com/item/main.nhn?code=011700',
#   'value': 1790},
#  {'market_cap(억원)': 579,
#   'market_cap_rank': '코스피944위',
#   'open_value': 58500,
#   'title': '롯데지주우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=00499K',
#   'value': 58600},
#  {'market_cap(억원)': 577,
#   'market_cap_rank': '코스피945위',
#   'open_value': 859,
#   'title': '케이비아이동국실업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=001620',
#   'value': 874},
#  {'market_cap(억원)': 572,
#   'market_cap_rank': '코스피946위',
#   'open_value': 4595,
#   'title': '선창산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=002820',
#   'value': 4540},
#  {'market_cap(억원)': 569,
#   'market_cap_rank': '코스피947위',
#   'open_value': 7660,
#   'title': 'MH에탄올',
#   'url': 'https://finance.naver.com/item/main.nhn?code=023150',
#   'value': 7710},
#  {'market_cap(억원)': 567,
#   'market_cap_rank': '코스피948위',
#   'open_value': 18600,
#   'title': '두산퓨얼셀2우B',
#   'url': 'https://finance.naver.com/item/main.nhn?code=33626L',
#   'value': 19000},
#  {'market_cap(억원)': 562,
#   'market_cap_rank': '코스피949위',
#   'open_value': 31200,
#   'title': 'GS우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=078935',
#   'value': 31500},
#  {'market_cap(억원)': 561,
#   'market_cap_rank': None,
#   'open_value': 10810,
#   'title': 'KBSTAR 미국나스닥100',
#   'url': 'https://finance.naver.com/item/main.nhn?code=368590',
#   'value': 11005},
#  {'market_cap(억원)': 560,
#   'market_cap_rank': None,
#   'open_value': 11005,
#   'title': 'TRUE 나스닥 100 ETN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=570051',
#   'value': 11200},
#  {'market_cap(억원)': 558,
#   'market_cap_rank': None,
#   'open_value': 68715,
#   'title': 'TIGER 200IT레버리지',
#   'url': 'https://finance.naver.com/item/main.nhn?code=243880',
#   'value': 74390},
#  {'market_cap(억원)': 558,
#   'market_cap_rank': '코스피953위',
#   'open_value': 3585,
#   'title': 'WISCOM',
#   'url': 'https://finance.naver.com/item/main.nhn?code=024070',
#   'value': 3640},
#  {'market_cap(억원)': 554,
#   'market_cap_rank': '코스피954위',
#   'open_value': 34500,
#   'title': '전방',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000950',
#   'value': 33000},
#  {'market_cap(억원)': 553,
#   'market_cap_rank': '코스피955위',
#   'open_value': 5530,
#   'title': '우진플라임',
#   'url': 'https://finance.naver.com/item/main.nhn?code=049800',
#   'value': 5530},
#  {'market_cap(억원)': 551,
#   'market_cap_rank': '코스피956위',
#   'open_value': 1225,
#   'title': '폴루스바이오팜',
#   'url': 'https://finance.naver.com/item/main.nhn?code=007630',
#   'value': 1225},
#  {'market_cap(억원)': 548,
#   'market_cap_rank': None,
#   'open_value': 10805,
#   'title': 'TRUE S&P500 선물 ETN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=570050',
#   'value': 10950},
#  {'market_cap(억원)': 542,
#   'market_cap_rank': None,
#   'open_value': 14590,
#   'title': 'KODEX 코스피대형주',
#   'url': 'https://finance.naver.com/item/main.nhn?code=337140',
#   'value': 15050},
#  {'market_cap(억원)': 539,
#   'market_cap_rank': '코스피959위',
#   'open_value': 4100,
#   'title': '컨버즈',
#   'url': 'https://finance.naver.com/item/main.nhn?code=109070',
#   'value': 4100},
#  {'market_cap(억원)': 537,
#   'market_cap_rank': '코스피960위',
#   'open_value': 973,
#   'title': '주연테크',
#   'url': 'https://finance.naver.com/item/main.nhn?code=044380',
#   'value': 983},
#  {'market_cap(억원)': 535,
#   'market_cap_rank': None,
#   'open_value': 27685,
#   'title': 'HANARO 200선물레버리지',
#   'url': 'https://finance.naver.com/item/main.nhn?code=304780',
#   'value': 29745},
#  {'market_cap(억원)': 534,
#   'market_cap_rank': '코스피962위',
#   'open_value': 1160,
#   'title': '한국전자홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006200',
#   'value': 1140},
#  {'market_cap(억원)': 531,
#   'market_cap_rank': '코스피963위',
#   'open_value': 3585,
#   'title': '평화홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010770',
#   'value': 3630},
#  {'market_cap(억원)': 530,
#   'market_cap_rank': None,
#   'open_value': 10600,
#   'title': '삼성 코스피 풋매도 ETN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=530053',
#   'value': 10600},
#  {'market_cap(억원)': 529,
#   'market_cap_rank': None,
#   'open_value': 18890,
#   'title': 'SMART KRX300',
#   'url': 'https://finance.naver.com/item/main.nhn?code=292500',
#   'value': 19580},
#  {'market_cap(억원)': 528,
#   'market_cap_rank': '코스피966위',
#   'open_value': 3540,
#   'title': 'SJM홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=025530',
#   'value': 3535},
#  {'market_cap(억원)': 526,
#   'market_cap_rank': '코스피967위',
#   'open_value': 1645,
#   'title': '체시스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=033250',
#   'value': 1645},
#  {'market_cap(억원)': 525,
#   'market_cap_rank': None,
#   'open_value': 99455,
#   'title': 'KBSTAR 국고채3년선물인버스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=282000',
#   'value': 99445},
#  {'market_cap(억원)': 523,
#   'market_cap_rank': '코스피969위',
#   'open_value': 3965,
#   'title': '진양산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003780',
#   'value': 4025},
#  {'market_cap(억원)': 520,
#   'market_cap_rank': '코스피970위',
#   'open_value': 2350,
#   'title': '화천기계',
#   'url': 'https://finance.naver.com/item/main.nhn?code=010660',
#   'value': 2365},
#  {'market_cap(억원)': 519,
#   'market_cap_rank': None,
#   'open_value': 5765,
#   'title': 'TIGER 농산물선물Enhanced(H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=137610',
#   'value': 5835},
#  {'market_cap(억원)': 512,
#   'market_cap_rank': '코스피972위',
#   'open_value': 603,
#   'title': '조일알미늄',
#   'url': 'https://finance.naver.com/item/main.nhn?code=018470',
#   'value': 609},
#  {'market_cap(억원)': 511,
#   'market_cap_rank': '코스피973위',
#   'open_value': 3710,
#   'title': '유엔젤',
#   'url': 'https://finance.naver.com/item/main.nhn?code=072130',
#   'value': 3870},
#  {'market_cap(억원)': 509,
#   'market_cap_rank': None,
#   'open_value': 24970,
#   'title': 'QV 소프트웨어 TOP5 ETN',
#   'url': 'https://finance.naver.com/item/main.nhn?code=550008',
#   'value': 25450},
#  {'market_cap(억원)': 502,
#   'market_cap_rank': None,
#   'open_value': 9730,
#   'title': 'KODEX 탄소효율그린뉴딜',
#   'url': 'https://finance.naver.com/item/main.nhn?code=375770',
#   'value': 10045},
#  {'market_cap(억원)': 497,
#   'market_cap_rank': '코스피976위',
#   'open_value': 54400,
#   'title': '두산2우B',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000157',
#   'value': 55600},
#  {'market_cap(억원)': 496,
#   'market_cap_rank': '코스피977위',
#   'open_value': 31150,
#   'title': '경인전자',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009140',
#   'value': 31550},
#  {'market_cap(억원)': 494,
#   'market_cap_rank': None,
#   'open_value': 3140,
#   'title': 'KODEX 건설',
#   'url': 'https://finance.naver.com/item/main.nhn?code=117700',
#   'value': 3210},
#  {'market_cap(억원)': 493,
#   'market_cap_rank': '코스피979위',
#   'open_value': 1005,
#   'title': '동원금속',
#   'url': 'https://finance.naver.com/item/main.nhn?code=018500',
#   'value': 1055},
#  {'market_cap(억원)': 492,
#   'market_cap_rank': '코스피980위',
#   'open_value': 2480,
#   'title': '대교우B',
#   'url': 'https://finance.naver.com/item/main.nhn?code=019685',
#   'value': 2530},
#  {'market_cap(억원)': 491,
#   'market_cap_rank': None,
#   'open_value': 5955,
#   'title': '대신 WTI원유 선물 ETN(H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=510001',
#   'value': 6140},
#  {'market_cap(억원)': 487,
#   'market_cap_rank': None,
#   'open_value': 14475,
#   'title': 'KODEX 미국러셀2000(H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=280930',
#   'value': 14970},
#  {'market_cap(억원)': 486,
#   'market_cap_rank': '코스피983위',
#   'open_value': 4025,
#   'title': '신송홀딩스',
#   'url': 'https://finance.naver.com/item/main.nhn?code=006880',
#   'value': 4110},
#  {'market_cap(억원)': 486,
#   'market_cap_rank': None,
#   'open_value': 100955,
#   'title': 'KOSEF 단기자금',
#   'url': 'https://finance.naver.com/item/main.nhn?code=130730',
#   'value': 100960},
#  {'market_cap(억원)': 481,
#   'market_cap_rank': '코스피985위',
#   'open_value': 61800,
#   'title': '롯데칠성우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=005305',
#   'value': 62000},
#  {'market_cap(억원)': 481,
#   'market_cap_rank': '코스피986위',
#   'open_value': 7630,
#   'title': '한성기업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003680',
#   'value': 7740},
#  {'market_cap(억원)': 479,
#   'market_cap_rank': None,
#   'open_value': 11505,
#   'title': 'TIGER 미국채10년선물',
#   'url': 'https://finance.naver.com/item/main.nhn?code=305080',
#   'value': 11400},
#  {'market_cap(억원)': 475,
#   'market_cap_rank': None,
#   'open_value': 101155,
#   'title': 'KOSEF 통안채1년',
#   'url': 'https://finance.naver.com/item/main.nhn?code=122260',
#   'value': 101155},
#  {'market_cap(억원)': 474,
#   'market_cap_rank': None,
#   'open_value': 4850,
#   'title': 'TRUE 레버리지 천연가스 선물 ETN(H)',
#   'url': 'https://finance.naver.com/item/main.nhn?code=570045',
#   'value': 4745},
#  {'market_cap(억원)': 466,
#   'market_cap_rank': None,
#   'open_value': 19155,
#   'title': 'KBSTAR KRX300',
#   'url': 'https://finance.naver.com/item/main.nhn?code=292050',
#   'value': 19820},
#  {'market_cap(억원)': 464,
#   'market_cap_rank': '코스피991위',
#   'open_value': 569,
#   'title': '엔케이물산',
#   'url': 'https://finance.naver.com/item/main.nhn?code=009810',
#   'value': 584},
#  {'market_cap(억원)': 463,
#   'market_cap_rank': None,
#   'open_value': 17555,
#   'title': 'TIGER 미국다우존스30',
#   'url': 'https://finance.naver.com/item/main.nhn?code=245340',
#   'value': 17825},
#  {'market_cap(억원)': 462,
#   'market_cap_rank': '코스피993위',
#   'open_value': 16300,
#   'title': '이화산업',
#   'url': 'https://finance.naver.com/item/main.nhn?code=000760',
#   'value': 16500},
#  {'market_cap(억원)': 461,
#   'market_cap_rank': '코스피994위',
#   'open_value': 925,
#   'title': '이스타코',
#   'url': 'https://finance.naver.com/item/main.nhn?code=015020',
#   'value': 1075},
#  {'market_cap(억원)': 459,
#   'market_cap_rank': '코스피995위',
#   'open_value': 6890,
#   'title': '하이트론',
#   'url': 'https://finance.naver.com/item/main.nhn?code=019490',
#   'value': 6840},
#  {'market_cap(억원)': 457,
#   'market_cap_rank': '코스피996위',
#   'open_value': 3630,
#   'title': '진도',
#   'url': 'https://finance.naver.com/item/main.nhn?code=088790',
#   'value': 3670},
#  {'market_cap(억원)': 456,
#   'market_cap_rank': '코스피997위',
#   'open_value': 27400,
#   'title': '솔루스첨단소재2우B',
#   'url': 'https://finance.naver.com/item/main.nhn?code=33637L',
#   'value': 27700},
#  {'market_cap(억원)': 452,
#   'market_cap_rank': '코스피998위',
#   'open_value': 40450,
#   'title': '대한항공우',
#   'url': 'https://finance.naver.com/item/main.nhn?code=003495',
#   'value': 40700},
#  {'market_cap(억원)': 451,
#   'market_cap_rank': None,
#   'open_value': 11275,
#   'title': 'TIGER KRX인터넷K-뉴딜',
#   'url': 'https://finance.naver.com/item/main.nhn?code=365000',
#   'value': 11570},
#  {'market_cap(억원)': 450,
#   'market_cap_rank': '코스피1000위',
#   'open_value': 1205,
#   'title': '태양금속',
#   'url': 'https://finance.naver.com/item/main.nhn?code=004100',
#   'value': 1225},
#  ...]

# %% [markdown]
# ### 4. CSV로 저장하기

# %%
import pandas as pd

finance_list_df = pd.DataFrame(finance_list)

finance_list_df
# Out:
#                             title  ... market_cap_rank
# 0                            삼성전자  ...           코스피1위
# 1                          SK하이닉스  ...           코스피2위
# 2                           NAVER  ...           코스피3위
# 3                            LG화학  ...           코스피4위
# 4                           삼성전자우  ...           코스피5위
# ...                           ...  ...             ...
# 1573                        동양3우B  ...        코스피1574위
# 1574                 KBSTAR 200건설  ...            None
# 1575           KBSTAR 팔라듐선물인버스(H)  ...            None
# 1576   KBSTAR 미국장기국채선물인버스2X(합성 H)  ...            None
# 1577  QV 인버스 레버리지 WTI원유 선물 ETN(H)  ...            None
#
# [1578 rows x 6 columns]

# %%
finance_list_df.to_csv("finance.csv")
